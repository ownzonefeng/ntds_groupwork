# %% [markdown]
# # [NTDS'18] milestone 4: graph signal processing
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Rodrigo Pena](https://people.epfl.ch/254838), [EPFL LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `<05>`
# * Students: `<Wentao Feng, Yunbei Wang, Yan Fu, Zhaodong Sun>`
# * Dataset: `<Flight route>`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to do some Graph Signal Processing (GSP) on the data of your project.
#
# ### A note about plotting
#
# There are several questions in this milestone that ask you to plot a signal on your network.
# There are several ways from which you could approach it.
# In all cases, compute the position of the nodes a single time at the beginning, as this is likely to be a costly operation.
# Using a single layout for all the graph plots will also make it easier to compare the plots.
# Indeed, the only thing changing between plots is the signal displayed.
# You can represent the features/labels lying on the graph via node **colors**.
# To do so, make sure to have a consistent color map throughout and remember to display a colorbar and scale in all plots, so that we can tell what numbers the colors represent.
#
# * An option is to use the **Laplacian eigenmaps** that you have seen in the previous milestone to embed your graph on the plane. For example:
#   ```
#   from matplotlib import pyplot as plt
#   plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], c=signal, alpha=0.5)
#   plt.colorbar()
#   ```
# * Another option is to use the plotting capabilities of **[NetworkX](https://networkx.github.io)**.
#   See the documentation of its [drawing methods](https://networkx.github.io/documentation/stable/reference/drawing.html).
#   For example:
#   ```
#   import networkx as nx
#   graph = nx.from_scipy_sparse_matrix(adjacency)
#   coords = nx.spring_layout(graph)  # Force-directed layout.
#   coords = eigenvectors[:, 1:3]  # Laplacian eigenmaps.
#   nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
#   nx.draw_networkx_edges(graph, coords, alpha=0.3)
#   ```
# * Another option is to use the plotting capabilities of the **[PyGSP](https://github.com/epfl-lts2/pygsp)**, a Python package for Graph Signal Processing.
#   **Note that your are forbidden to use the PyGSP for anything else than plotting.**
#   See the documentation of its [plotting utilities](https://pygsp.readthedocs.io/en/stable/reference/plotting.html).
#   For example:
#   ```
#   import pygsp as pg
#   graph = pg.graphs.Graph(adjacency)
#   graph.set_coordinates('spring')  # Force-directed layout.
#   graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps.
#   graph.plot_signal(signal)
#   ```
# * Yet another option is to save your graph on disk, use **[Gephi](https://gephi.org)** externally, to visualize the graph, save the graph with the Gephi coordinates and finally load the nodes coordinates back into the notebook.
#
# We encourage you to try all the above methods before making your choice. Then be consistent and use only one throughout the milestone.
# NetworkX and PyGSP should already be installed in your environement. If that's not the case, install with `conda install networkx pygsp` (after activating the `ntds_2018` environment).

# %% [markdown]
# ## 0 - Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'pyunlocbox'` error when running the below cell, install the [pyunlocbox](https://github.com/epfl-lts2/pyunlocbox) with `conda install pyunlocbox` (after activating the `ntds_2018` environment).

# %%
import numpy as np
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from pyunlocbox import functions, solvers

# %%
import networkx as nx
import pandas as pd
from matplotlib import cm

# %% [markdown]
# For this milestone, all we will need is a set of features/labels for each of the nodes on the network, as well as the Laplacian, $L,$ and Gradient, $\nabla_G,$ matrices that you have computed for your network while working on milestone 3.
#
# Import those objects in the cell below (or recompute the Laplacian and Gradient from your stored adjacency matrix, if you wish).
#
# _Note_: If your features/labels are not floating-point numbers, please convert them. For example, if your data has labels "cat" and "dog" for nodes that represent cats or dogs, respectively, you may assign the number `1.0` for the label "cat" and the number `-1.0` for the label "dog".

# %%
adjacency =  np.load('symm_adj.npy')
weighted_adj = np.load('weighted_adj.npy')
W = weighted_adj + weighted_adj.T

# %%
idx_GC = np.load("idx_largest_component.npy")
GC = W[idx_GC, :]
GC = GC[:, idx_GC]
GC_sparse = sparse.csr_matrix(GC)
W_GC = W[idx_GC, :][:, idx_GC]

# %%
n_degree = np.sum(GC,axis=0)
D = sparse.diags(n_degree)
laplacian_combinatorial = D - GC_sparse

# Your code here.
D_root_inv = sparse.diags(np.sqrt(1/n_degree))
laplacian_normalized =  D_root_inv.dot(laplacian_combinatorial.dot(D_root_inv))

# %%
PortGeo = pd.read_csv('PortGeo.csv')

# %%
idx_hub = np.where(n_degree>1000)

# %%
PortGeo.set_index('index').loc[idx_GC[idx_hub]]
# Out:
#       Port IATA  ICAO   Latitude   Longitude  \
# index
# 458    CDG  CDG  LFPG  49.012798    2.550000
# 1588   LHR  LHR  EGLL  51.470600   -0.461941
# 2144   PEK  PEK  ZBAA  40.080101  116.584999
# 163    ATL  ATL  KATL  33.636700  -84.428101
# 2075   ORD  ORD  KORD  41.978600  -87.904800
#
#                                                    Name         Country
# index
# 458             Charles de Gaulle International Airport          France
# 1588                            London Heathrow Airport  United Kingdom
# 2144              Beijing Capital International Airport           China
# 163    Hartsfield Jackson Atlanta International Airport   United States
# 2075               Chicago O'Hare International Airport   United States

# %%
n_nodes = GC.shape[0]
label = np.zeros(n_nodes)
for i in idx_hub[0]:
    label += GC[:,i]
label[label>0]=1

# %%
latitude = np.zeros(n_nodes)
longtitude = np.zeros(n_nodes)
for i in range(len(GC)):
    if len(PortGeo.loc[PortGeo['index']==idx_GC[i]].Latitude.get_values()):
        latitude[i] = PortGeo.loc[PortGeo['index']==idx_GC[i]].Latitude.get_values()[0]
        longtitude[i] = PortGeo.loc[PortGeo['index']==idx_GC[i]].Longitude.get_values()[0]

# %%
edge_idx = 0
n_edges = np.sum(GC > 0) / 2
gradient = np.zeros([int(n_edges), int(n_nodes)])
for i in range(n_nodes):
    for j in range(i + 1, n_nodes):
        if W_GC[i, j] > 0:
            gradient[edge_idx, i] = -np.sqrt(W_GC[i, j]) * (label[j] - label[i])
            gradient[edge_idx, j] = -gradient[edge_idx, i]
            edge_idx += 1

# %%
#laplacian = laplacian_normalized# Your code here.
laplacian = laplacian_combinatorial
# gradient = # Your code here. ?S.T @ x
labels = label# Your code here.s
n_nodes = GC.shape[0]# Your code here.

# %% [markdown]
# **ANSWER**
#
# As shown above, we decide to choose the airports linked to top-5 busiest airports as label 1, and the rest airports not-linked to these 5 airport as label 0.

# %% [markdown]
# ## 1 - Graph Fourier Transform
#
# In this section we will observe how your feature/label vector looks like in the "Graph Fourier" domain.

# %% [markdown]
# ### Question 1
#
# Compute the Fourier basis vectors and the Laplacian eigenvalues. Make sure to order those from smaller to larger, $\lambda_0 \leq \lambda_1 \leq \dots \leq \lambda_{N-1},$ and use the same ordering for the Fourier basis vectors.

# %% [markdown]
# Plot the first 3 and the last Fourier basis vectors as signals on your graph. Clearly indicate which plot belongs to which basis vector.

# %%
e,U = np.linalg.eigh(laplacian.A)

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(U[:,0],label='The First Eigenvector')
ax.plot(U[:,1],label='The Second Eigenvector')
ax.plot(U[:,2],label='The Third Eigenvector')
ax.plot(U[:,-1],label='The Last Eigenvector')
ax.legend()
ax.set_title('Plot for eigenvector')
ax.set_xlabel('Vertex Index')
# Out:
# Text(0.5,0,'Vertex Index')

# %% [markdown]
# ### Question 2
#
# What can you observe in terms of local variations when comparing the basis vectors corresponding to the smallest eigenvalues to those corresponding to the largest eigenvalue? How would this justify the interpretation of the eigenvalues as "graph frequencies"?

# %% [markdown]
# **Your answer here.**
#
# The graph Laplacian eigenvectors associated with low frequencies $\lambda_0$ vary slowly across the graph; i.e., if two vertices with similar values are connected by an edge with a large weight, the values of the eigenvector at those locations are likely to be similar. The eigenvectors associated with larger eigenvalues oscillate more rapidly and are more likely to have dissimilar values on vertices connected by an edge with high weight.
#
# The higher index the eigenvalue is, the more zero passings there are.
#
# $\lambda_1$ Fiedler vector.
#
# $\lambda_l$ = $min {f L f} $ f is perpendicular to a span space ${u_0,...,u_{l-1}}$

# %% [markdown]
# ### Question 3
#
# Implement a function that returns the Graph Fourier Transform (GFT) of a given vector $x \in \mathbb{R}^{N},$ with respect to your graph, and a function that computes the corresponding inverse GFT (iGFT).

# %%
def GFT(x):
    return U.T.dot(x)# Your code here.

def iGFT(x): 
    return U.dot(x)# Your code here.

# %% [markdown]
# ### Question 4
#
# Plot your feature/label vector as a signal on your graph

# %%
def G_edgelist(adj):
    x,y = np.nonzero(adj)
    G = nx.Graph()
    for i in range(len(x)):
        G.add_edge(x[i],y[i],weight=adj[x[i]][y[i]])
    return G.edges()

# %%
def G_pos(x,y,n_nodes):
    pos_dic = {}
    for i in range(n_nodes):
        pos_dic[i] = x[i],y[i]
    return pos_dic

# %%
top5 = np.zeros_like(GC)
top5[:,idx_hub] = GC[:,idx_hub]
top5[idx_hub,:] =GC[idx_hub,:]

# %%
edgetop5 = G_edgelist(top5)
pos = G_pos(x=longtitude,y=latitude,n_nodes=n_nodes)
G=nx.from_numpy_array(GC)

# %%
plt.figure(figsize=(15*1.8,15))

nx.draw(G, pos=pos,node_size=30,width=0.1,node_color=labels,cmap='RdYlBu',edgelist=edgetop5)
plt.title('Plot for the top-5 busiest airports in our data',fontsize='30')
# Out:
# Text(0.5,1,'Plot for the top-5 busiest airports in our data')

# %% [markdown]
# Plot the absolute values of the GFT of your feature/label signal as a function of the graph eigenvalues. Make sure to add a marker indicating the position of each graph eigenvalue, and remember to properly name the axes.

# %%
plt.scatter(x=e, y=abs(GFT(labels)).ravel()/np.max(abs(GFT(labels))),s=10)
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.title('Label in Spectral Domain with GFT')
plt.grid()

# %% [markdown]
# ### Question 5
#
# Discuss the behavior of the GFT that you plotted in the last question via comparing the plot of your label signal and those of the Fourier basis of Question 1. Would you consider your labels a "low-pass" or "high-pass" signal, or yet something else entirely?

# %% [markdown]
# **Your answer here.**
#
# It is a low-pass signal.

# %% [markdown]
# ## 2 - Filtering on graphs
#
# In this section we will check how filtered Dirac impulses diffuse on your graph.

# %% [markdown]
# ### Question 6
#
# Implement the following three filter kernels and the graph filtering operation.
#
# - The **heat kernel** is supposed to take in a vector of eigenvalues `e` and a parameter `t` and output a vector of evaluations of the heat kernel at those eigenvalues (see the course slides for help).
# - The **inverse filter** kernel is supposed to take in a vector of eigenvalues `e` and a parameter `t` and implement spectrally the  filter defined in the node domain by $f_{out}  = (I + t L)^{-1} f_{in},$ where $f_{in}, f_{out} \in \mathbb{R}^{N}$ are, repectively, the input and output signals to the filter.
# - The **rectangle kernel** takes in a vector of eigenvalues `e` and parameters `l_min` and `l_max` and returns `1.0` at coordinates satisfying $(e[l] \geq l_{min}) \wedge (e[l] \leq l_{max}),$ and `0.0` otherwise.
# - The **graph filtering** operation takes a graph signal $x \in \mathbb{R}^{N}$, a spectral graph `kernel` and a set of keyworded variables, and returns the corresponding filtered signal.
#     - _Hint:_ Remember that you have implemented the `GFT` and `iGFT` operations in Question 3.
#     - The `**kwargs` is a placeholder to collect supplementary pairs of keyword-values that are not known by the implementation before execution time.
#       The `kwargs` variable is a dictionary whose keyes and values are the parameter names and values.
#       This is useful to allow both `graph_filter(x, heat_kernel, tau=1.0)` and `graph_filter(x, rectangle_kernel, lambda_min=0.0, lambda_max=1.0)` to be valid calls from the same implementation.
#       One can then defer the keyword-value assignment to the `kernel` call: `foo = kernel(bar, **kwargs)`.

# %%
def heat_kernel(e, t):
    return np.diag(np.exp(-t*e))

def inverse_kernel(e, t):
    return np.diag(1/(1+t*e))

def rectangle_kernel(e, l_min, l_max):
    return np.diag((e>=l_min)&(e<=l_max).astype(int))

def graph_filter(x, kernel, **kwargs):
    return (GFT((kernel(**kwargs))) @ U).dot(x)# Your code here.

# %% [markdown]
# ### Question 7
#
# Plot all three filter kernels in the **spectral domain**. Remember to properly name the axes and title the plots. Choose filter parameters that best approximate the behavior of the GFT of your feature/label signal (as seen in Question 4).

# %%
# Your code here.
plt.figure(figsize=(8*1.6,8))

test_label = labels

plt.subplot(221)
plt.scatter(x=e, y=abs(GFT(test_label)).ravel()/np.max(abs(GFT(test_label))),s=5)
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.title('Label in Spectral Domain with GFT')
plt.grid()

plt.subplot(222)
plt.plot(e,np.diag(heat_kernel(e=e,t=0.05)),'-')
plt.title('Heat Kernel in Spectral Domain')
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.grid()

plt.subplot(223)
plt.plot(e,np.diag(inverse_kernel(e=e,t=0.15)),'-')
plt.title('Inverse Kernel in Spectral Domain')
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.grid()

plt.subplot(224)
plt.plot(e,np.diag(rectangle_kernel(e=e,l_min=-0.001,l_max=50)),'-')
plt.title('Rectangular Kernel in Spectral Domain')
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.grid()

plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### Question 8
#
# Consider two Dirac impulses arbitrarily placed on your graph. Plot their filtered versions by the three filter kernels implemented in Question 6.

# %%
Dirac_impulse = np.zeros(n_nodes)
#idx_Dirac = idx_hub[0][np.random.randint(5,size=2)]
idx_Dirac = idx_hub[0][[2,3]]
Dirac_impulse[idx_Dirac]=1

# %%
Dirac = np.zeros_like(GC)
Dirac[:,idx_Dirac] = GC[:,idx_Dirac]
Dirac[idx_Dirac,:] = GC[idx_Dirac,:]
edgeDirac = G_edgelist(Dirac)

# %%
test_label = Dirac_impulse
test_label = test_label.reshape(len(test_label),1)

# %%
plt.figure(figsize=(12*1.6,12))

kernel = heat_kernel
heat_taus = np.array([0.01,0.05,0.5,1])

for i in range(len(heat_taus)):
    plt.subplot(2,2,i+1)
    heat = np.diag(heat_kernel(e=e,t=heat_taus[i]))
    heat = heat.reshape(len(heat),1)
    nx.draw(G, pos=pos,node_size=10, node_color=iGFT(heat*GFT(test_label)).ravel(),width=0,cmap='Blues')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('Filtered by Heat Kernel with tau = %0.3f'%heat_taus[i])

# %%
plt.figure(figsize=(12*1.6,12))

kernel = inverse_kernel
inverse_taus = np.array([0.5,1,3,5])

for i in range(len(inverse_taus)):
    plt.subplot(2,2,i+1)
    inverse = np.diag(inverse_kernel(e=e,t=inverse_taus[i]))
    inverse = inverse.reshape(len(inverse),1)
    nx.draw(G, pos=pos,node_size=10, node_color=iGFT(inverse*GFT(test_label)).ravel(),width=0,cmap='Blues')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('Filtered by Inverse Kernel with tau = %0.3f'%inverse_taus[i])

# %%
plt.figure(figsize=(12*1.6,12))

kernel = rectangle_kernel
l_maxs = np.array([200,100,5,1])

for i in range(len(heat_taus)):
    plt.subplot(2,2,i+1)
    rec = np.diag(rectangle_kernel(e=e,l_min=-0.001, l_max=l_maxs[i]))
    rec = rec.reshape(len(rec),1)
    nx.draw(G, pos=pos,node_size=10, node_color=iGFT(rec*GFT(test_label)).ravel(),width=0,cmap='Blues')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('Filtered by Rectangular Kernel with l_max = %0.3f'%l_maxs[i])

# %% [markdown]
# Comment on the "diffusion" of the Diracs induced by the filters. What does it say about the "communication" of information across your network? Relate that to the **network connectivity** measures that you analyzed during the previous milestones.

# %% [markdown]
# **Your answer here.**
#
# The three filters above are all low-frequency filters and after filtering, the energy of Diracs signal is averaged and spread to its neighbour airports. First it diffuses to its nearest airports, and with time goes by (in our case, with the cutoff frequency of filters going down) if diffuses to worldwide airports. The more remote and less links one airport is, the slower Diracs signal diffuses to it.

# %% [markdown]
# ## 3 - De-noising
#
# In this section we will add some centered Gaussian noise to your feature/label signal and attempt to recover it.

# %% [markdown]
# ### Question 9
#
# In the cell below, set the noise variance $\sigma^2$ by making sure that the signal-to-noise ratio $SNR = \frac{\operatorname{Var}(\text{labels})}{\sigma^2}$ is about  $1.5$.
#
# _Note:_ Actually, you might want to play with the noise variance here and set it to different values and see how the denoising filters behave.

# %%
SNR = 1.5

noise_variance = np.var(labels)/SNR# Your code here.
noisy_measurements = labels.ravel() + np.sqrt(noise_variance) * np.random.randn(n_nodes)
noisy_measurements = noisy_measurements.reshape(noisy_measurements.shape[0],1)

# %% [markdown]
# ### Question 10
#
# In the denoising setting, a common graph signal processing assumption is that the signal $z$ that we want to recover is "smooth", in the sense that $\|\nabla_G z\|_2 = \sqrt{z^{\top} L z}$ is small, while remaining "close" to the measurements that we start with. This leads to denoising by solving the following optimization problem:
#
# $$
# z^\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \|z - y\|_2^2 + \gamma z^{\top} L z,
# $$
#
# where $y \in \mathbb{R}^{N}$ is the vector of noisy measurements.
#
# Derive the close form solution to this problem giving $z^\star$ as a function of $y$, $\gamma$ and $L$. Does this solution correspond to any graph filtering operation that you know?

# %% [markdown]
# **Your answer here.**
#
# Compute the gradient of optimizationproblem and set the gradient to zero. Because we can easily find out that the optimization problem is convex, thus $z^\star$ making gradient to zero is the solution.
#
# $$z^\star = (1 + \gamma L)^{-1} y$$
#
# It has a similar form to inverse filter.

# %% [markdown]
# ### Question 11
#
# Now, denoise the noisy measurements by passing them through the filters that you implemented in Question 6. Choose the filter parameters based on the behavior of the GFT of your original label signal (this is the prior knowledge that you input to the problem).

# %%
f_in = noisy_measurements
heat_denoise = graph_filter(x=f_in, kernel=heat_kernel, e=e,t = 0.05)

inverse_denoise = graph_filter(x=f_in, kernel=inverse_kernel, e=e,t = 0.15)

rec_denoise = graph_filter(x=f_in, kernel=rectangle_kernel, e=e,l_min=-0.001,l_max=50)

# %%
plt.figure(figsize=(15,10))

plt.subplot(321)
plt.plot(labels)
plt.title('Origin signal')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(322)
plt.plot(abs(f_in))
plt.title('Noisy signal')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(323)
plt.plot(abs(heat_denoise))
plt.title('Noise denoised by heat filter')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(324)
plt.plot(abs(inverse_denoise))
plt.title('Noise denoised by inverse filter')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(325)
plt.plot(abs(rec_denoise))
plt.title('Noise denoised by rectangle filter')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# Plot, on your graph, the original label signal, the noisy measurements, and the three denoised version obtained above. Report on each plot the value of the corresponding relative error
# $$
# \text{rel-err} = \frac{\|\text{labels} - z \|_2}{\|\text{labels}\|_2},
# $$
# where $z$ is the plotted signal.

# %%
# Your code here.
def rel_err(label,z):
    return np.linalg.norm((label-z.ravel()))/np.linalg.norm(label)

# %%
print(rel_err(labels,heat_denoise))
# Out:
# 0.7856090612676778

# %%
print(rel_err(labels,inverse_denoise))
# Out:
# 0.7857906508093466

# %%
print(rel_err(labels,rec_denoise))
# Out:
# 0.811730541996733

# %% [markdown]
# Finally, overlay on the same plot the GFT of all five signals above.

# %%
# Your code here.
plt.figure(figsize=(15,10))
plt.subplot(321)
plt.plot(e,GFT(labels))
plt.title('Origin signal in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(322)
plt.plot(e,GFT(f_in))
plt.title('Noisy signal in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(323)
plt.plot(e,GFT(heat_denoise))
plt.title('Noise denoised by heat filter in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(324)
plt.plot(e,GFT(inverse_denoise))
plt.title('Noise denoised by inverse filter in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(325)
plt.plot(e,GFT(rec_denoise))
plt.title('Noise denoised by rectangle filter in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### Question 12
#
# Comment on which denoised version seems to best match the original label signal. What is the underlying assumption behind the three filtering approaches? Do you think it holds for your label signal? Why?

# %% [markdown]
# **Your answer here.**
#
# From plot and rec_err we know the heat filter and inverse filter are doing the best, which coincides to the result from Question 10.
#
# From question 7 we can see all filters are low frequency filter(rectangle filter can be modified into a band-pass filter but it does not hurt the following conclusion), they assume that the noisy clearly has different frequency than origin signal, that's why they can denoise.
#
# However, we are using Gaussian noise and this noise is uniformly distributed in spectral domain. So we can see that all filters are not doing very well in denoising.

# %% [markdown]
# ## 4 - Transductive learning
#
# It is often the case in large networks that we can only afford to query properties/labels on a small subset of nodes. Nonetheless, if the underlying labels signal is "regular" enough, we might still be able to recover a good approximation of it by solving an offline variational problem, with constraints on the values of the measured nodes.
#
# In this section, we will be interested in solving such transductive learning problems by minimizing a (semi-) p-norm of the graph gradient applied to the signal of interest:
#
# $$
# \text{arg} \, \underset{z|_S = y}{\min} \|\nabla_G z\|_p^p,
# $$
#
# where $S$ is the set of measured nodes.
#
# In English, we can say that we are looking for solutions with small "aggregated local variations", as measured by $\|\nabla_G z\|_p^p = \sum_{i=1}^{n} \sum_{j=1}^{n} \left( \sqrt{W_{ij}} |z[i] - z[j]| \right)^p,$ while satisfying the measurement constraints $z[i] = y[i]$ for $i \in S.$
#
# We will work with two cases, according to the choices $p=1$ or $p=2.$ For $p=1,$ the problem is known as "interpolation by graph total-variation minimization," whereas for $p=2$ it is sometimes called "interpolation by Tikhonov regularization".
#
# In order to solve these variational problems with the black-box solver provided to you, you will use the [pyunlocbox](https://pyunlocbox.readthedocs.io). This toolbox implements iterative solvers based on so-called ["proximal-splitting"](https://en.wikipedia.org/wiki/Proximal_gradient_method) methods.

# %% [markdown]
# ### Question 13
#
# Throughout this section, we will consider only a binarized version of your label signal. If your variable `labels` currently has values other than $\{-1, 1\},$ threshold them so that those are the only values taken in this vector. This can be done for example by choosing a number $t \in \mathbb{R}$ and then setting $\text{labels_bin}[i] = 1$ if $\text{labels}[i] \geq t$ and $\text{labels_bin}[i] = 0$ otherwise.

# %%
idx_hub = np.array([179, 225, 243, 383, 492])
label = np.zeros(n_nodes)
for i in idx_hub:
    label += GC[:,i]
label[label>0]=1
label[label==0]=-1

labels_bin = np.copy(label)
labels_bin[label >= 0] = 1
labels_bin[label < 0] = -1

# %% [markdown]
# Now, subsample this binarized label signal by $70\%$ by choosing, uniformly at random, $30\%$ of the nodes whose labels we will keep.
#
# You will do this by computing a "measurement mask" vector `w` with `1.0`'s at the measured coordinates, and $0.0$'s otherwise.

# %%
mn_ratio = 0.3
m = int(mn_ratio * n_nodes)  # Number of measurements.
w = np.ones_like(labels_bin)
mask_idx = np.random.permutation(n_nodes)[0:(n_nodes - m)]
w[mask_idx] = 0

# %% [markdown]
# Plot the subsampled signal on the graph. _Hint:_ you might want to set to `numpy.nan` the values of the un-measured nodes for a cleaner plot.

# %%
# Your code here.
labels_bin_plt = np.copy(labels_bin)
labels_bin_plt[mask_idx] = np.nan

# %%
fig, ax = plt.subplots(1,2,figsize = [18,6])
ax[0].scatter(np.arange(n_nodes), labels_bin,marker='|')
ax[0].set_title('Original signal', fontdict={'fontsize':15})
ax[1].scatter(np.arange(n_nodes), labels_bin_plt,marker='|')
ax[1].set_title('Subsampled signal', fontdict={'fontsize':15})
for i in range(len(ax)):
    ax[i].tick_params(labelsize = 16)
    ax[i].set_xlabel('Nodes',fontdict={'fontsize':15})
    ax[i].set_ylabel('Labels',fontdict={'fontsize':15})

# %% [markdown]
# ### Interlude
#
# For the solution of the variational problems you can use the following function as a "black-box".
#
# You will just need to provide a `gradient` matrix (which you should already have from Section 0), and an orthogonal projection operator `P` onto the span of the measured coordinates (made precise in the next question).

# %%
def graph_pnorm_interpolation(gradient, P, x0=None, p=1., **kwargs):
    r"""
    Solve an interpolation problem via gradient p-norm minimization.

    A signal :math:`x` is estimated from its measurements :math:`y = A(x)` by solving
    :math:`\text{arg}\underset{z \in \mathbb{R}^n}{\min}
    \| \nabla_G z \|_p^p \text{ subject to } Az = y` 
    via a primal-dual, forward-backward-forward algorithm.

    Parameters
    ----------
    gradient : array_like
        A matrix representing the graph gradient operator
    P : callable
        Orthogonal projection operator mapping points in :math:`z \in \mathbb{R}^n` 
        onto the set satisfying :math:`A P(z) = A z`.
    x0 : array_like, optional
        Initial point of the iteration. Must be of dimension n.
        (Default is `numpy.random.randn(n)`)
    p : {1., 2.}
    kwargs :
        Additional solver parameters, such as maximum number of iterations
        (maxit), relative tolerance on the objective (rtol), and verbosity
        level (verbosity). See :func:`pyunlocbox.solvers.solve` for the full
        list of options.

    Returns
    -------
    x : array_like
        The solution to the optimization problem.

    """
    
    grad = lambda z: gradient.dot(z)
    div = lambda z: gradient.transpose().dot(z)

    # Indicator function of the set satisfying :math:`y = A(z)`
    f = functions.func()
    f._eval = lambda z: 0
    f._prox = lambda z, gamma: P(z)

    # :math:`\ell_1` norm of the dual variable :math:`d = \nabla_G z`
    g = functions.func()
    g._eval = lambda z: np.sum(np.abs(grad(z)))
    g._prox = lambda d, gamma: functions._soft_threshold(d, gamma)

    # :math:`\ell_2` norm of the gradient (for the smooth case)
    h = functions.norm_l2(A=grad, At=div)

    stepsize = (0.9 / (1. + scipy.sparse.linalg.norm(gradient, ord='fro'))) ** p

    solver = solvers.mlfbf(L=grad, Lt=div, step=stepsize)

    if p == 1.:
        problem = solvers.solve([f, g, functions.dummy()], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    if p == 2.:
        problem = solvers.solve([f, functions.dummy(), h], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    else:
        return x0

# %% [markdown]
# ### Question 14
#
# During the iterations of the algorithm used for solving the variational problem, we have to make sure that the labels at the measured nodes stay the same. We will do this by means of an operator `P` which, given a vector $a \in \mathbb{R}^{N},$ returns another vector $b \in \mathbb{R}^{N}$ satisfying $b[i] = \text{labels_bin}[i]$ for every node $i$ in the set $S$ of known labels, and $b[i] = a[i]$ otherwise. Write in the cell below the function for this orthogonal projection operator `P`.
#
# _Hint:_ remember you have already computed the mask `w`.

# %%
def P(a):
    b = a
    b[np.where(w == 1)] = labels_bin[np.where(w == 1)]
    return b

# %% [markdown]
# ### Question 15
#
# Solve the variational problems for $p = 1$ and $p = 2$. Record the solution for the $1-$norm minimization under `sol_1norm_min` and the one for $2-$norm minimization under `sol_2norm_min`.
#
# Compute also binarized versions of these solutions by thresholding the values with respect to $0$, that is, non-negative values become `1.0`, while negative values become `-1.0`. Store those binarized versions under `sol_1norm_bin` and `sol_2norm_bin`, respectively.

# %%
gradient = sparse.csr_matrix(gradient)
x0 = np.random.randn(n_nodes)
x0_bin = np.random.randn(n_nodes)

# %%
sol_1norm_min = graph_pnorm_interpolation(gradient, P, x0 = x0, p=1., maxit = 2000)

sol_2norm_min = graph_pnorm_interpolation(gradient, P, x0 = x0, p=2., maxit = 2000)

threshold = 0

sol_1norm_bin = graph_pnorm_interpolation(gradient, P, x0 = x0_bin, p=1., maxit = 2000)
sol_1norm_bin[sol_1norm_bin >= 0] = 1
sol_1norm_bin[sol_1norm_bin < 0] = -1

sol_2norm_bin = graph_pnorm_interpolation(gradient, P, x0 = x0_bin, p=2., maxit = 2000)
sol_2norm_bin[sol_2norm_bin >= 0] = 1
sol_2norm_bin[sol_2norm_bin < 0] = -1
# Out:
# Solution found after 981 iterations:
#     objective function f(sol) = 6.124734e+05
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 2.523282e+08
#     stopping criterion: RTOL
# Solution found after 996 iterations:
#     objective function f(sol) = 6.153313e+05
#     stopping criterion: RTOL
# Solution found after 1702 iterations:
#     objective function f(sol) = 8.019086e+05
#     stopping criterion: RTOL

# %%
rel_err_comp = {'sol_1norm_min': rel_err(label, sol_1norm_min),
                'sol_2norm_min': rel_err(label, sol_2norm_min),
                'sol_1norm_bin': rel_err(labels_bin, sol_1norm_bin),
                'sol_2norm_bin': rel_err(labels_bin, sol_2norm_bin),}

# %%
for key in rel_err_comp.keys():
    print(('relative error for ' + key + ' is {:2.2f}').format(rel_err_comp[key]))
# Out:
# relative error for sol_1norm_min is 25.07
# relative error for sol_2norm_min is 25.07
# relative error for sol_1norm_bin is 1.53
# relative error for sol_2norm_bin is 1.53

# %%
fig, ax = plt.subplots(3,2,figsize=(12,10))
ax[0,0].remove()
ax[0,1].remove()
axs = fig.add_subplot(311)
x = np.arange(n_nodes)
axs.scatter(x, labels_bin, marker='|')
axs.set_xlabel('Nodes',fontdict={'fontsize':14})
axs.set_ylabel('Labels',fontdict={'fontsize':14})
axs.set_title('Original binarized signal',fontdict={'fontsize':14})
axs.tick_params(labelsize = 12)
for i, key in enumerate(rel_err_comp.keys()):
    exec('%s = %s' % ('temp', key))
    loc = [int(i / 2) + 1, i % 2]
    ax[loc[0], loc[1]].tick_params(labelsize = 12)
    ax[loc[0], loc[1]].scatter(x, temp, marker='|')
    ax[loc[0], loc[1]].set_xlabel('Nodes',fontdict={'fontsize':14})
    ax[loc[0], loc[1]].set_ylabel('Labels',fontdict={'fontsize':14})
    ax[loc[0], loc[1]].set_title(key, fontdict={'fontsize':14})
fig.tight_layout()

# %% [markdown]
# Plot, on your graph, the original `labels_bin` signal, as well as the solutions to the variational problems (both binarized and otherwise). Indicate on each plot the value of the relative error $\text{rel-err} = \frac{\|\text{labels_bin} - z\|_2}{\|\text{labels_bin}\|_2}$, where $z$ is the signal in the corresponding plot.

# %% [markdown]
# ### Question 16
#
# Now that you have got a feeling for the sort of solutions that the transductive learning problems studied can give, we will see what is the effect of the number of measurements on the accuracy of both $p-$norm minimization problems.
#
# Towards this goal, you will write a `phase_transition()` function. This function will basically go over all the procedures that you have implemented in this section, but for varying numbers of measurements and thresholding values. It will also compute the relative error, $\text{rel-err},$ of the solutions and average them over a number of trials.
#
# The output of the `phase_transition()` function has to be a matrix with `len(mn_ratios)` columns and `len(thresholds)` rows. Each pixel $(i,j)$ in the output matrix has to contain the average, over `n_trials` trials, of the relative error $\text{rel-err}$ in the binarized (with threshold `thresholds[i]`) solution given by `graph_pnorm_interpolation()` from observing an `mn_ratios[j]` fraction of nodes. The randomness comes from a different choice of mask `w` at each trial, hence the averaging.
#
# The interest of this phase transition matrix is to assess what level of recovery error one could expect for a certain fraction of measurements and a certain threshold level.

# %%
def phase_transition(mn_ratios, thresholds, n_trials, labels_bin, p):

    # Create sample mask.
    
    # Solve p-norm interpolation.
    
    # Aggregate.
    row = len(thresholds)
    col = len(mn_ratios)
    pt_matrix = np.zeros([row, col])
    idx = np.array(np.meshgrid(np.arange(row), np.arange(col), np.arange(n_trials))).T.reshape(-1, 3)
    for i in idx:
        threshold_i = thresholds[i[0]]
        mn_ratios_i = mn_ratios[i[1]]
        m = int(mn_ratios_i * n_nodes)  # Number of measurements.
        w = np.ones_like(labels_bin)
        mask_idx = np.random.RandomState(i[0] * 10 + i[1]).permutation(n_nodes)[0:(n_nodes - m)]
        w[mask_idx] = 0
        x0_bin = np.random.randn(n_nodes)
        x0_bin[w == 1] = labels_bin[w == 1]
        sol_p_norm_bin = graph_pnorm_interpolation(gradient, P, x0 = x0_bin, p=p, maxit = 3000)
        pred_label = np.zeros_like(sol_p_norm_bin) - 1
        pred_label[sol_p_norm_bin >= threshold_i] = 1
        pt_matrix[i[0], i[1]] += rel_err(labels_bin, pred_label)
    return pt_matrix / n_trials

# %% [markdown]
# ### Question 17
#
# Pick 5 "m/n" ratios in $(0, 1)$ and 5 threshold levels in $(-1, 1)$ and run the `phase_transition()` function with `n_trials` = 20, for both $p = 1$ and $p = 2$.

# %%
mn_ratios = np.matlib.linspace(0.2 * np.random.rand(1), 1, 5, endpoint=False)
print('mn_ratios:', (*np.round(mn_ratios,2)))
thresholds = np.matlib.linspace(0.4 * np.random.rand(1) - 1, 1, 5, endpoint=False)
print('thresholds:', (*np.round(thresholds,2)))
# Out:
# mn_ratios: 0.01 0.21 0.4 0.6 0.8
# thresholds: -0.87 -0.5 -0.12 0.25 0.63

# %%
pt_matrix_1norm = phase_transition(mn_ratios, thresholds, n_trials=20, labels_bin=labels_bin, p=1)

pt_matrix_2norm = phase_transition(mn_ratios, thresholds, n_trials=20, labels_bin=labels_bin, p=2)
# Out:
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.270011e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 3.638715e+04
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.180933e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.610245e+04
#     stopping criterion: RTOL
# Solution found after 944 iterations:
#     objective function f(sol) = 6.264368e+05
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.031542e+05
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.183878e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.193071e+04
#     stopping criterion: RTOL
# Solution found after 958 iterations:
#     objective function f(sol) = 6.257772e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.651936e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.231335e+05
#     stopping criterion: RTOL
# Solution found after 994 iterations:
#     objective function f(sol) = 6.279749e+05
#     stopping criterion: RTOL
# Solution found after 968 iterations:
#     objective function f(sol) = 6.193665e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.594818e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.634872e+04
#     stopping criterion: RTOL
# Solution found after 1020 iterations:
#     objective function f(sol) = 6.338311e+05
#     stopping criterion: RTOL
# Solution found after 969 iterations:
#     objective function f(sol) = 6.155880e+05
#     stopping criterion: RTOL
# Solution found after 973 iterations:
#     objective function f(sol) = 6.271674e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.924817e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.425691e+04
#     stopping criterion: RTOL
# Solution found after 1011 iterations:
#     objective function f(sol) = 6.170766e+05
#     stopping criterion: RTOL
# Solution found after 962 iterations:
#     objective function f(sol) = 6.140529e+05
#     stopping criterion: RTOL
# Solution found after 965 iterations:
#     objective function f(sol) = 6.260774e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.898503e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.737343e+04
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.184014e+05
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.297654e+05
#     stopping criterion: RTOL
# Solution found after 972 iterations:
#     objective function f(sol) = 6.196201e+05
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 4.789446e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.630179e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 2.628057e+04
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.200057e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.107838e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.527866e+03
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.612501e+03
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.210715e+05
#     stopping criterion: RTOL
# Solution found after 971 iterations:
#     objective function f(sol) = 6.104275e+05
#     stopping criterion: RTOL
# Solution found after 959 iterations:
#     objective function f(sol) = 6.096264e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.035486e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.450693e+04
#     stopping criterion: RTOL
# Solution found after 1010 iterations:
#     objective function f(sol) = 6.199481e+05
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.195538e+05
#     stopping criterion: RTOL
# Solution found after 972 iterations:
#     objective function f(sol) = 6.256341e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.204368e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.651323e+04
#     stopping criterion: RTOL
# Solution found after 1028 iterations:
#     objective function f(sol) = 6.273898e+05
#     stopping criterion: RTOL
# Solution found after 967 iterations:
#     objective function f(sol) = 6.163348e+05
#     stopping criterion: RTOL
# Solution found after 952 iterations:
#     objective function f(sol) = 6.157143e+05
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 4.735289e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.712717e+04
#     stopping criterion: RTOL
# Solution found after 53 iterations:
#     objective function f(sol) = 2.786385e+04
#     stopping criterion: RTOL
# Solution found after 983 iterations:
#     objective function f(sol) = 6.228955e+05
#     stopping criterion: RTOL
# Solution found after 959 iterations:
#     objective function f(sol) = 6.117548e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.817111e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.567345e+04
#     stopping criterion: RTOL
# Solution found after 1011 iterations:
#     objective function f(sol) = 6.258987e+05
#     stopping criterion: RTOL
# Solution found after 945 iterations:
#     objective function f(sol) = 6.109637e+05
#     stopping criterion: RTOL
# Solution found after 981 iterations:
#     objective function f(sol) = 6.277435e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.026444e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.582461e+04
#     stopping criterion: RTOL
# Solution found after 1028 iterations:
#     objective function f(sol) = 6.317598e+05
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.156967e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.060175e+04
#     stopping criterion: RTOL
# Solution found after 962 iterations:
#     objective function f(sol) = 6.263031e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.584608e+04
#     stopping criterion: RTOL
# Solution found after 1008 iterations:
#     objective function f(sol) = 6.189797e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 3.668718e+04
#     stopping criterion: RTOL
# Solution found after 966 iterations:
#     objective function f(sol) = 6.237209e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.951878e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.461201e+04
#     stopping criterion: RTOL
# Solution found after 1006 iterations:
#     objective function f(sol) = 6.202108e+05
#     stopping criterion: RTOL
# Solution found after 980 iterations:
#     objective function f(sol) = 6.198541e+05
#     stopping criterion: RTOL
# Solution found after 927 iterations:
#     objective function f(sol) = 6.060231e+05
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 5.183433e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.679895e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.604567e+03
#     stopping criterion: RTOL
# Solution found after 966 iterations:
#     objective function f(sol) = 6.188192e+05
#     stopping criterion: RTOL
# Solution found after 964 iterations:
#     objective function f(sol) = 6.226147e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.562014e+04
#     stopping criterion: RTOL
# Solution found after 50 iterations:
#     objective function f(sol) = 5.638161e+04
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.168795e+05
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.266282e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.461893e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 5.228680e+04
#     stopping criterion: RTOL
# Solution found after 937 iterations:
#     objective function f(sol) = 6.223835e+05
#     stopping criterion: RTOL
# Solution found after 991 iterations:
#     objective function f(sol) = 6.204718e+05
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.185297e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.443018e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.986527e+04
#     stopping criterion: RTOL
# Solution found after 934 iterations:
#     objective function f(sol) = 6.158189e+05
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.141235e+05
#     stopping criterion: RTOL
# Solution found after 954 iterations:
#     objective function f(sol) = 6.081835e+05
#     stopping criterion: RTOL
# Solution found after 972 iterations:
#     objective function f(sol) = 6.301391e+05
#     stopping criterion: RTOL
# Solution found after 946 iterations:
#     objective function f(sol) = 6.178600e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.467047e+04
#     stopping criterion: RTOL
# Solution found after 1014 iterations:
#     objective function f(sol) = 6.294786e+05
#     stopping criterion: RTOL
# Solution found after 986 iterations:
#     objective function f(sol) = 6.202610e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.209090e+04
#     stopping criterion: RTOL
# Solution found after 943 iterations:
#     objective function f(sol) = 6.148315e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.600768e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.747325e+03
#     stopping criterion: RTOL
# Solution found after 994 iterations:
#     objective function f(sol) = 6.323964e+05
#     stopping criterion: RTOL
# Solution found after 965 iterations:
#     objective function f(sol) = 6.240601e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.726769e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.754867e+04
#     stopping criterion: RTOL
# Solution found after 1021 iterations:
#     objective function f(sol) = 6.348083e+05
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.189798e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.352031e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.920095e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.782480e+04
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.164162e+05
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.273319e+05
#     stopping criterion: RTOL
# Solution found after 966 iterations:
#     objective function f(sol) = 6.171121e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.138276e+03
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.799436e+03
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.109227e+05
#     stopping criterion: RTOL
# Solution found after 1003 iterations:
#     objective function f(sol) = 6.319140e+05
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 4.237493e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.075175e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.328063e+03
#     stopping criterion: RTOL
# Solution found after 1009 iterations:
#     objective function f(sol) = 6.273149e+05
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.253576e+05
#     stopping criterion: RTOL
# Solution found after 966 iterations:
#     objective function f(sol) = 6.236492e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.797879e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.666565e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 2.849746e+04
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.214889e+05
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.239418e+05
#     stopping criterion: RTOL
# Solution found after 37 iterations:
#     objective function f(sol) = 4.879960e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.527110e+03
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.147415e+05
#     stopping criterion: RTOL
# Solution found after 996 iterations:
#     objective function f(sol) = 6.232188e+05
#     stopping criterion: RTOL
# Solution found after 956 iterations:
#     objective function f(sol) = 6.232571e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.549651e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.721442e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 2.834630e+04
#     stopping criterion: RTOL
# Solution found after 970 iterations:
#     objective function f(sol) = 6.200734e+05
#     stopping criterion: RTOL
# Solution found after 973 iterations:
#     objective function f(sol) = 6.205816e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.871220e+04
#     stopping criterion: RTOL
# Solution found after 931 iterations:
#     objective function f(sol) = 6.215377e+05
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.222368e+05
#     stopping criterion: RTOL
# Solution found after 983 iterations:
#     objective function f(sol) = 6.208825e+05
#     stopping criterion: RTOL
# Solution found after 972 iterations:
#     objective function f(sol) = 6.298885e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.803564e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.467483e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.683017e+03
#     stopping criterion: RTOL
# Solution found after 988 iterations:
#     objective function f(sol) = 6.205732e+05
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.264404e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.949333e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.799965e+04
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.184983e+05
#     stopping criterion: RTOL
# Solution found after 986 iterations:
#     objective function f(sol) = 6.256524e+05
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.326310e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.746280e+04
#     stopping criterion: RTOL
# Solution found after 936 iterations:
#     objective function f(sol) = 6.240261e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 2.786418e+04
#     stopping criterion: RTOL
# Solution found after 963 iterations:
#     objective function f(sol) = 6.132791e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 4.360357e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.875594e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.580657e+04
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.219910e+05
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.144455e+05
#     stopping criterion: RTOL
# Solution found after 954 iterations:
#     objective function f(sol) = 6.153755e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.945584e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.477612e+04
#     stopping criterion: RTOL
# Solution found after 1003 iterations:
#     objective function f(sol) = 6.077314e+05
#     stopping criterion: RTOL
# Solution found after 970 iterations:
#     objective function f(sol) = 6.151375e+05
#     stopping criterion: RTOL
# Solution found after 977 iterations:
#     objective function f(sol) = 6.309884e+05
#     stopping criterion: RTOL
# Solution found after 940 iterations:
#     objective function f(sol) = 6.189634e+05
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 5.438267e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 2.798035e+04
#     stopping criterion: RTOL
# Solution found after 1007 iterations:
#     objective function f(sol) = 6.295308e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 3.948634e+04
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 4.815718e+04
#     stopping criterion: RTOL
# Solution found after 947 iterations:
#     objective function f(sol) = 6.240685e+05
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.117589e+05
#     stopping criterion: RTOL
# Solution found after 995 iterations:
#     objective function f(sol) = 6.350034e+05
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.249798e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.849287e+04
#     stopping criterion: RTOL
# Solution found after 936 iterations:
#     objective function f(sol) = 6.265861e+05
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 8.033857e+03
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.150257e+05
#     stopping criterion: RTOL
# Solution found after 974 iterations:
#     objective function f(sol) = 6.259018e+05
#     stopping criterion: RTOL
# Solution found after 941 iterations:
#     objective function f(sol) = 6.168119e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.457136e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.246792e+05
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.217450e+05
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 4.371480e+04
#     stopping criterion: RTOL
# Solution found after 934 iterations:
#     objective function f(sol) = 6.067664e+05
#     stopping criterion: RTOL
# Solution found after 935 iterations:
#     objective function f(sol) = 6.216682e+05
#     stopping criterion: RTOL
# Solution found after 998 iterations:
#     objective function f(sol) = 6.259080e+05
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.215368e+05
#     stopping criterion: RTOL
# Solution found after 972 iterations:
#     objective function f(sol) = 6.332381e+05
#     stopping criterion: RTOL
# Solution found after 963 iterations:
#     objective function f(sol) = 6.263233e+05
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 5.550073e+04
#     stopping criterion: RTOL
# Solution found after 1013 iterations:
#     objective function f(sol) = 6.242334e+05
#     stopping criterion: RTOL
# Solution found after 961 iterations:
#     objective function f(sol) = 6.231648e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 3.925429e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.819201e+04
#     stopping criterion: RTOL
# Solution found after 946 iterations:
#     objective function f(sol) = 6.280336e+05
#     stopping criterion: RTOL
# Solution found after 1014 iterations:
#     objective function f(sol) = 6.296092e+05
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.194289e+05
#     stopping criterion: RTOL
# Solution found after 967 iterations:
#     objective function f(sol) = 6.217380e+05
#     stopping criterion: RTOL
# Solution found after 50 iterations:
#     objective function f(sol) = 4.730973e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 5.736053e+04
#     stopping criterion: RTOL
# Solution found after 1010 iterations:
#     objective function f(sol) = 6.218292e+05
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.204207e+05
#     stopping criterion: RTOL
# Solution found after 956 iterations:
#     objective function f(sol) = 6.289776e+05
#     stopping criterion: RTOL
# Solution found after 952 iterations:
#     objective function f(sol) = 6.271069e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.618599e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 7.838711e+03
#     stopping criterion: RTOL
# Solution found after 968 iterations:
#     objective function f(sol) = 6.132859e+05
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.209880e+05
#     stopping criterion: RTOL
# Solution found after 931 iterations:
#     objective function f(sol) = 6.179111e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.672346e+04
#     stopping criterion: RTOL
# Solution found after 1011 iterations:
#     objective function f(sol) = 6.244974e+05
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.251885e+05
#     stopping criterion: RTOL
# Solution found after 970 iterations:
#     objective function f(sol) = 6.302615e+05
#     stopping criterion: RTOL
# Solution found after 942 iterations:
#     objective function f(sol) = 6.187240e+05
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 5.593030e+04
#     stopping criterion: RTOL
# Solution found after 1006 iterations:
#     objective function f(sol) = 6.224894e+05
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.275892e+05
#     stopping criterion: RTOL
# Solution found after 948 iterations:
#     objective function f(sol) = 6.167037e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.891140e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.726420e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 8.407903e+03
#     stopping criterion: RTOL
# Solution found after 967 iterations:
#     objective function f(sol) = 6.221001e+05
#     stopping criterion: RTOL
# Solution found after 954 iterations:
#     objective function f(sol) = 6.116514e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.988943e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 5.718228e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.657798e+03
#     stopping criterion: RTOL
# Solution found after 971 iterations:
#     objective function f(sol) = 6.246773e+05
#     stopping criterion: RTOL
# Solution found after 957 iterations:
#     objective function f(sol) = 6.260394e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.928708e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.561929e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.333990e+05
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 3.249827e+04
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.268657e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.861204e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.615452e+04
#     stopping criterion: RTOL
# Solution found after 1011 iterations:
#     objective function f(sol) = 6.315171e+05
#     stopping criterion: RTOL
# Solution found after 991 iterations:
#     objective function f(sol) = 6.203641e+05
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.312479e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.111295e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.510254e+04
#     stopping criterion: RTOL
# Solution found after 991 iterations:
#     objective function f(sol) = 6.246956e+05
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.218042e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.169377e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.100275e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.815766e+04
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.068736e+05
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.227477e+05
#     stopping criterion: RTOL
# Solution found after 961 iterations:
#     objective function f(sol) = 6.197748e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.094083e+04
#     stopping criterion: RTOL
# Solution found after 50 iterations:
#     objective function f(sol) = 5.701398e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.705412e+03
#     stopping criterion: RTOL
# Solution found after 996 iterations:
#     objective function f(sol) = 6.237811e+05
#     stopping criterion: RTOL
# Solution found after 971 iterations:
#     objective function f(sol) = 6.148248e+05
#     stopping criterion: RTOL
# Solution found after 955 iterations:
#     objective function f(sol) = 6.288341e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.354141e+04
#     stopping criterion: RTOL
# Solution found after 974 iterations:
#     objective function f(sol) = 6.186554e+05
#     stopping criterion: RTOL
# Solution found after 54 iterations:
#     objective function f(sol) = 3.408168e+04
#     stopping criterion: RTOL
# Solution found after 958 iterations:
#     objective function f(sol) = 6.160703e+05
#     stopping criterion: RTOL
# Solution found after 941 iterations:
#     objective function f(sol) = 6.220856e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.604662e+04
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.309787e+05
#     stopping criterion: RTOL
# Solution found after 987 iterations:
#     objective function f(sol) = 6.332711e+05
#     stopping criterion: RTOL
# Solution found after 964 iterations:
#     objective function f(sol) = 6.238003e+05
#     stopping criterion: RTOL
# Solution found after 948 iterations:
#     objective function f(sol) = 6.242795e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.728916e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.962591e+03
#     stopping criterion: RTOL
# Solution found after 964 iterations:
#     objective function f(sol) = 6.181558e+05
#     stopping criterion: RTOL
# Solution found after 962 iterations:
#     objective function f(sol) = 6.236869e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.112862e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.789154e+04
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.927749e+03
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.199979e+05
#     stopping criterion: RTOL
# Solution found after 960 iterations:
#     objective function f(sol) = 6.193646e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.938250e+04
#     stopping criterion: RTOL
# Solution found after 942 iterations:
#     objective function f(sol) = 6.255597e+05
#     stopping criterion: RTOL
# Solution found after 1014 iterations:
#     objective function f(sol) = 6.262398e+05
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.333132e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.188123e+04
#     stopping criterion: RTOL
# Solution found after 938 iterations:
#     objective function f(sol) = 6.203325e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.745810e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.274994e+05
#     stopping criterion: RTOL
# Solution found after 970 iterations:
#     objective function f(sol) = 6.232501e+05
#     stopping criterion: RTOL
# Solution found after 954 iterations:
#     objective function f(sol) = 6.172722e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.663185e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.645762e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.137107e+05
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.322438e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.484864e+03
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.722391e+03
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.428255e+04
#     stopping criterion: RTOL
# Solution found after 980 iterations:
#     objective function f(sol) = 6.269563e+05
#     stopping criterion: RTOL
# Solution found after 971 iterations:
#     objective function f(sol) = 6.178172e+05
#     stopping criterion: RTOL
# Solution found after 957 iterations:
#     objective function f(sol) = 6.174792e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.906268e+04
#     stopping criterion: RTOL
# Solution found after 936 iterations:
#     objective function f(sol) = 6.246136e+05
#     stopping criterion: RTOL
# Solution found after 998 iterations:
#     objective function f(sol) = 6.253544e+05
#     stopping criterion: RTOL
# Solution found after 994 iterations:
#     objective function f(sol) = 6.271048e+05
#     stopping criterion: RTOL
# Solution found after 986 iterations:
#     objective function f(sol) = 6.224814e+05
#     stopping criterion: RTOL
# Solution found after 954 iterations:
#     objective function f(sol) = 6.251852e+05
#     stopping criterion: RTOL
# Solution found after 51 iterations:
#     objective function f(sol) = 5.626336e+04
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.172181e+05
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 8.451977e+03
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.366371e+04
#     stopping criterion: RTOL
# Solution found after 941 iterations:
#     objective function f(sol) = 6.232617e+05
#     stopping criterion: RTOL
# Solution found after 936 iterations:
#     objective function f(sol) = 6.250598e+05
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.292688e+05
#     stopping criterion: RTOL
# Solution found after 983 iterations:
#     objective function f(sol) = 6.287599e+05
#     stopping criterion: RTOL
# Solution found after 970 iterations:
#     objective function f(sol) = 6.201407e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.805179e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 5.769406e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 2.651021e+04
#     stopping criterion: RTOL
# Solution found after 1008 iterations:
#     objective function f(sol) = 6.287920e+05
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.257803e+05
#     stopping criterion: RTOL
# Solution found after 939 iterations:
#     objective function f(sol) = 6.214576e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.649114e+04
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.179202e+05
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.264307e+05
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 4.161713e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.946156e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.594847e+04
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 2.892197e+04
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.264689e+05
#     stopping criterion: RTOL
# Solution found after 958 iterations:
#     objective function f(sol) = 6.164606e+05
#     stopping criterion: RTOL
# Solution found after 962 iterations:
#     objective function f(sol) = 6.294408e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.552317e+04
#     stopping criterion: RTOL
# Solution found after 1041 iterations:
#     objective function f(sol) = 6.239133e+05
#     stopping criterion: RTOL
# Solution found after 1006 iterations:
#     objective function f(sol) = 6.274887e+05
#     stopping criterion: RTOL
# Solution found after 960 iterations:
#     objective function f(sol) = 6.213819e+05
#     stopping criterion: RTOL
# Solution found after 936 iterations:
#     objective function f(sol) = 6.172668e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.584436e+04
#     stopping criterion: RTOL
# Solution found after 1031 iterations:
#     objective function f(sol) = 6.309404e+05
#     stopping criterion: RTOL
# Solution found after 994 iterations:
#     objective function f(sol) = 6.264511e+05
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.192761e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.958540e+04
#     stopping criterion: RTOL
# Solution found after 949 iterations:
#     objective function f(sol) = 6.251486e+05
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.844279e+03
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.354149e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.088809e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.773436e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.507124e+04
#     stopping criterion: RTOL
# Solution found after 995 iterations:
#     objective function f(sol) = 6.286718e+05
#     stopping criterion: RTOL
# Solution found after 969 iterations:
#     objective function f(sol) = 6.219836e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.179255e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.729196e+04
#     stopping criterion: RTOL
# Solution found after 942 iterations:
#     objective function f(sol) = 6.276005e+05
#     stopping criterion: RTOL
# Solution found after 1014 iterations:
#     objective function f(sol) = 6.286172e+05
#     stopping criterion: RTOL
# Solution found after 996 iterations:
#     objective function f(sol) = 6.173620e+05
#     stopping criterion: RTOL
# Solution found after 974 iterations:
#     objective function f(sol) = 6.218761e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.846921e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.467120e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.263480e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 3.210964e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.205018e+04
#     stopping criterion: RTOL
# Solution found after 944 iterations:
#     objective function f(sol) = 6.207470e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.691279e+03
#     stopping criterion: RTOL
# Solution found after 1004 iterations:
#     objective function f(sol) = 6.034514e+05
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.189138e+05
#     stopping criterion: RTOL
# Solution found after 947 iterations:
#     objective function f(sol) = 6.128056e+05
#     stopping criterion: RTOL
# Solution found after 946 iterations:
#     objective function f(sol) = 6.239630e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.439128e+04
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.273808e+05
#     stopping criterion: RTOL
# Solution found after 974 iterations:
#     objective function f(sol) = 6.216027e+05
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.280097e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.955656e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.734052e+04
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.224047e+05
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.264109e+05
#     stopping criterion: RTOL
# Solution found after 955 iterations:
#     objective function f(sol) = 6.163437e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.889174e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.567640e+04
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 2.770693e+04
#     stopping criterion: RTOL
# Solution found after 983 iterations:
#     objective function f(sol) = 6.275590e+05
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.275123e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.960153e+04
#     stopping criterion: RTOL
# Solution found after 937 iterations:
#     objective function f(sol) = 6.216698e+05
#     stopping criterion: RTOL
# Solution found after 981 iterations:
#     objective function f(sol) = 6.116959e+05
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.254007e+05
#     stopping criterion: RTOL
# Solution found after 966 iterations:
#     objective function f(sol) = 6.249311e+05
#     stopping criterion: RTOL
# Solution found after 956 iterations:
#     objective function f(sol) = 6.282137e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.697651e+03
#     stopping criterion: RTOL
# Solution found after 1008 iterations:
#     objective function f(sol) = 6.306185e+05
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.220066e+05
#     stopping criterion: RTOL
# Solution found after 947 iterations:
#     objective function f(sol) = 6.162807e+05
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 4.743663e+04
#     stopping criterion: RTOL
# Solution found after 935 iterations:
#     objective function f(sol) = 6.230995e+05
#     stopping criterion: RTOL
# Solution found after 1003 iterations:
#     objective function f(sol) = 6.251430e+05
#     stopping criterion: RTOL
# Solution found after 995 iterations:
#     objective function f(sol) = 6.358868e+05
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.286906e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.954895e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.606681e+04
#     stopping criterion: RTOL
# Solution found after 998 iterations:
#     objective function f(sol) = 6.253463e+05
#     stopping criterion: RTOL
# Solution found after 971 iterations:
#     objective function f(sol) = 6.170706e+05
#     stopping criterion: RTOL
# Solution found after 973 iterations:
#     objective function f(sol) = 6.358231e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 4.979363e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.487850e+04
#     stopping criterion: RTOL
# Solution found after 1020 iterations:
#     objective function f(sol) = 6.266548e+05
#     stopping criterion: RTOL
# Solution found after 981 iterations:
#     objective function f(sol) = 6.267291e+05
#     stopping criterion: RTOL
# Solution found after 960 iterations:
#     objective function f(sol) = 6.176539e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.721123e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.622202e+04
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.221046e+05
#     stopping criterion: RTOL
# Solution found after 1010 iterations:
#     objective function f(sol) = 6.253096e+05
#     stopping criterion: RTOL
# Solution found after 949 iterations:
#     objective function f(sol) = 6.213499e+05
#     stopping criterion: RTOL
# Solution found after 955 iterations:
#     objective function f(sol) = 6.165708e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.550034e+03
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.134439e+05
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.161397e+05
#     stopping criterion: RTOL
# Solution found after 952 iterations:
#     objective function f(sol) = 6.133556e+05
#     stopping criterion: RTOL
# Solution found after 962 iterations:
#     objective function f(sol) = 6.244418e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.619277e+04
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.195569e+05
#     stopping criterion: RTOL
# Solution found after 977 iterations:
#     objective function f(sol) = 6.192930e+05
#     stopping criterion: RTOL
# Solution found after 968 iterations:
#     objective function f(sol) = 6.169511e+05
#     stopping criterion: RTOL
# Solution found after 950 iterations:
#     objective function f(sol) = 6.171328e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.397856e+04
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.237136e+05
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.257117e+05
#     stopping criterion: RTOL
# Solution found after 956 iterations:
#     objective function f(sol) = 6.194219e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.007827e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.573535e+04
#     stopping criterion: RTOL
# Solution found after 995 iterations:
#     objective function f(sol) = 6.302160e+05
#     stopping criterion: RTOL
# Solution found after 976 iterations:
#     objective function f(sol) = 6.224981e+05
#     stopping criterion: RTOL
# Solution found after 974 iterations:
#     objective function f(sol) = 6.336131e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.537900e+04
#     stopping criterion: RTOL
# Solution found after 931 iterations:
#     objective function f(sol) = 6.199956e+05
#     stopping criterion: RTOL
# Solution found after 1018 iterations:
#     objective function f(sol) = 6.222538e+05
#     stopping criterion: RTOL
# Solution found after 1004 iterations:
#     objective function f(sol) = 6.222065e+05
#     stopping criterion: RTOL
# Solution found after 950 iterations:
#     objective function f(sol) = 6.195480e+05
#     stopping criterion: RTOL
# Solution found after 960 iterations:
#     objective function f(sol) = 6.228746e+05
# ...
#     stopping criterion: RTOL
# Solution found after 83 iterations:
#     objective function f(sol) = 3.226586e+04
#     stopping criterion: RTOL
# Solution found after 127 iterations:
#     objective function f(sol) = 2.154194e+04
#     stopping criterion: RTOL
# Solution found after 154 iterations:
#     objective function f(sol) = 2.017328e+04
#     stopping criterion: RTOL
# Solution found after 170 iterations:
#     objective function f(sol) = 1.786521e+04
#     stopping criterion: RTOL
# Solution found after 54 iterations:
#     objective function f(sol) = 3.198937e+04
#     stopping criterion: RTOL
# Solution found after 94 iterations:
#     objective function f(sol) = 2.834153e+04
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 2.366800e+04
#     stopping criterion: RTOL
# Solution found after 133 iterations:
#     objective function f(sol) = 2.426513e+04
#     stopping criterion: RTOL
# Solution found after 169 iterations:
#     objective function f(sol) = 1.905697e+04
#     stopping criterion: RTOL
# Solution found after 75 iterations:
#     objective function f(sol) = 2.793608e+04
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 2.553286e+04
#     stopping criterion: RTOL
# Solution found after 124 iterations:
#     objective function f(sol) = 2.417236e+04
#     stopping criterion: RTOL
# Solution found after 139 iterations:
#     objective function f(sol) = 2.096907e+04
#     stopping criterion: RTOL
# Solution found after 159 iterations:
#     objective function f(sol) = 1.884701e+04
#     stopping criterion: RTOL
# Solution found after 52 iterations:
#     objective function f(sol) = 2.962297e+04
#     stopping criterion: RTOL
# Solution found after 98 iterations:
#     objective function f(sol) = 2.739059e+04
#     stopping criterion: RTOL
# Solution found after 135 iterations:
#     objective function f(sol) = 2.008760e+04
#     stopping criterion: RTOL
# Solution found after 136 iterations:
#     objective function f(sol) = 2.484256e+04
#     stopping criterion: RTOL
# Solution found after 171 iterations:
#     objective function f(sol) = 1.790907e+04
#     stopping criterion: RTOL
# Solution found after 59 iterations:
#     objective function f(sol) = 2.899894e+04
#     stopping criterion: RTOL
# Solution found after 88 iterations:
#     objective function f(sol) = 2.756951e+04
#     stopping criterion: RTOL
# Solution found after 110 iterations:
#     objective function f(sol) = 2.699349e+04
#     stopping criterion: RTOL
# Solution found after 147 iterations:
#     objective function f(sol) = 1.910482e+04
#     stopping criterion: RTOL
# Solution found after 167 iterations:
#     objective function f(sol) = 1.700628e+04
#     stopping criterion: RTOL
# Solution found after 93 iterations:
#     objective function f(sol) = 3.060274e+04
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.911392e+04
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 2.275174e+04
#     stopping criterion: RTOL
# Solution found after 150 iterations:
#     objective function f(sol) = 2.184888e+04
#     stopping criterion: RTOL
# Solution found after 146 iterations:
#     objective function f(sol) = 2.230930e+04
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 2.807275e+04
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 2.506892e+04
#     stopping criterion: RTOL
# Solution found after 134 iterations:
#     objective function f(sol) = 2.299118e+04
#     stopping criterion: RTOL
# Solution found after 137 iterations:
#     objective function f(sol) = 2.292699e+04
#     stopping criterion: RTOL
# Solution found after 168 iterations:
#     objective function f(sol) = 1.820725e+04
#     stopping criterion: RTOL
# Solution found after 87 iterations:
#     objective function f(sol) = 2.628073e+04
#     stopping criterion: RTOL
# Solution found after 95 iterations:
#     objective function f(sol) = 3.227137e+04
#     stopping criterion: RTOL
# Solution found after 131 iterations:
#     objective function f(sol) = 2.386982e+04
#     stopping criterion: RTOL
# Solution found after 132 iterations:
#     objective function f(sol) = 2.313270e+04
#     stopping criterion: RTOL
# Solution found after 155 iterations:
#     objective function f(sol) = 1.999303e+04
#     stopping criterion: RTOL
# Solution found after 94 iterations:
#     objective function f(sol) = 3.111129e+04
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 2.294931e+04
#     stopping criterion: RTOL
# Solution found after 130 iterations:
#     objective function f(sol) = 2.291787e+04
#     stopping criterion: RTOL
# Solution found after 153 iterations:
#     objective function f(sol) = 2.045666e+04
#     stopping criterion: RTOL
# Solution found after 171 iterations:
#     objective function f(sol) = 1.841308e+04
#     stopping criterion: RTOL
# Solution found after 69 iterations:
#     objective function f(sol) = 3.455439e+04
#     stopping criterion: RTOL
# Solution found after 102 iterations:
#     objective function f(sol) = 2.874427e+04
#     stopping criterion: RTOL
# Solution found after 111 iterations:
#     objective function f(sol) = 2.708784e+04
#     stopping criterion: RTOL
# Solution found after 130 iterations:
#     objective function f(sol) = 2.529481e+04
#     stopping criterion: RTOL
# Solution found after 166 iterations:
#     objective function f(sol) = 1.698580e+04
#     stopping criterion: RTOL
# Solution found after 65 iterations:
#     objective function f(sol) = 3.051614e+04
#     stopping criterion: RTOL
# Solution found after 94 iterations:
#     objective function f(sol) = 2.710404e+04
#     stopping criterion: RTOL
# Solution found after 111 iterations:
#     objective function f(sol) = 2.572784e+04
#     stopping criterion: RTOL
# Solution found after 153 iterations:
#     objective function f(sol) = 1.970536e+04
#     stopping criterion: RTOL
# Solution found after 155 iterations:
#     objective function f(sol) = 2.138079e+04
#     stopping criterion: RTOL
# Solution found after 63 iterations:
#     objective function f(sol) = 2.822587e+04
#     stopping criterion: RTOL
# Solution found after 100 iterations:
#     objective function f(sol) = 2.675857e+04
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 2.816127e+04
#     stopping criterion: RTOL
# Solution found after 148 iterations:
#     objective function f(sol) = 2.211500e+04
#     stopping criterion: RTOL
# Solution found after 156 iterations:
#     objective function f(sol) = 2.049042e+04
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 2.886486e+04
#     stopping criterion: RTOL
# Solution found after 99 iterations:
#     objective function f(sol) = 2.833703e+04
#     stopping criterion: RTOL
# Solution found after 144 iterations:
#     objective function f(sol) = 2.314156e+04
#     stopping criterion: RTOL
# Solution found after 140 iterations:
#     objective function f(sol) = 2.321665e+04
#     stopping criterion: RTOL
# Solution found after 163 iterations:
#     objective function f(sol) = 2.027783e+04
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.703793e+04
#     stopping criterion: RTOL
# Solution found after 84 iterations:
#     objective function f(sol) = 2.818590e+04
#     stopping criterion: RTOL
# Solution found after 132 iterations:
#     objective function f(sol) = 2.245338e+04
#     stopping criterion: RTOL
# Solution found after 147 iterations:
#     objective function f(sol) = 2.089976e+04
#     stopping criterion: RTOL
# Solution found after 175 iterations:
#     objective function f(sol) = 1.723363e+04
#     stopping criterion: RTOL
# Solution found after 73 iterations:
#     objective function f(sol) = 3.015035e+04
#     stopping criterion: RTOL
# Solution found after 121 iterations:
#     objective function f(sol) = 2.239601e+04
#     stopping criterion: RTOL
# Solution found after 122 iterations:
#     objective function f(sol) = 2.291062e+04
#     stopping criterion: RTOL
# Solution found after 141 iterations:
#     objective function f(sol) = 2.315806e+04
#     stopping criterion: RTOL
# Solution found after 169 iterations:
#     objective function f(sol) = 1.620872e+04
#     stopping criterion: RTOL
# Solution found after 70 iterations:
#     objective function f(sol) = 3.149554e+04
#     stopping criterion: RTOL
# Solution found after 81 iterations:
#     objective function f(sol) = 2.964133e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 2.513259e+04
#     stopping criterion: RTOL
# Solution found after 152 iterations:
#     objective function f(sol) = 2.159760e+04
#     stopping criterion: RTOL
# Solution found after 160 iterations:
#     objective function f(sol) = 2.085083e+04
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 2.870699e+04
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 2.884254e+04
#     stopping criterion: RTOL
# Solution found after 110 iterations:
#     objective function f(sol) = 2.495929e+04
#     stopping criterion: RTOL
# Solution found after 151 iterations:
#     objective function f(sol) = 2.298308e+04
#     stopping criterion: RTOL
# Solution found after 176 iterations:
#     objective function f(sol) = 1.704412e+04
#     stopping criterion: RTOL
# Solution found after 58 iterations:
#     objective function f(sol) = 2.861892e+04
#     stopping criterion: RTOL
# Solution found after 95 iterations:
#     objective function f(sol) = 2.684928e+04
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 2.315605e+04
#     stopping criterion: RTOL
# Solution found after 142 iterations:
#     objective function f(sol) = 2.024228e+04
#     stopping criterion: RTOL
# Solution found after 169 iterations:
#     objective function f(sol) = 1.841548e+04
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.016197e+04
#     stopping criterion: RTOL
# Solution found after 94 iterations:
#     objective function f(sol) = 2.909812e+04
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 2.247147e+04
#     stopping criterion: RTOL
# Solution found after 134 iterations:
#     objective function f(sol) = 2.231870e+04
#     stopping criterion: RTOL
# Solution found after 169 iterations:
#     objective function f(sol) = 1.766763e+04
#     stopping criterion: RTOL
# Solution found after 103 iterations:
#     objective function f(sol) = 2.598058e+04
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 2.458126e+04
#     stopping criterion: RTOL
# Solution found after 134 iterations:
#     objective function f(sol) = 2.353801e+04
#     stopping criterion: RTOL
# Solution found after 128 iterations:
#     objective function f(sol) = 2.446297e+04
#     stopping criterion: RTOL
# Solution found after 167 iterations:
#     objective function f(sol) = 1.750457e+04
#     stopping criterion: RTOL
# Solution found after 70 iterations:
#     objective function f(sol) = 3.088023e+04
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 2.598692e+04
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 2.287661e+04
#     stopping criterion: RTOL
# Solution found after 161 iterations:
#     objective function f(sol) = 1.983868e+04
#     stopping criterion: RTOL
# Solution found after 159 iterations:
#     objective function f(sol) = 1.967337e+04
#     stopping criterion: RTOL
# Solution found after 77 iterations:
#     objective function f(sol) = 2.852977e+04
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.926643e+04
#     stopping criterion: RTOL
# Solution found after 122 iterations:
#     objective function f(sol) = 2.575543e+04
#     stopping criterion: RTOL
# Solution found after 152 iterations:
#     objective function f(sol) = 1.965527e+04
#     stopping criterion: RTOL
# Solution found after 166 iterations:
#     objective function f(sol) = 1.919592e+04
#     stopping criterion: RTOL
# Solution found after 56 iterations:
#     objective function f(sol) = 3.167666e+04
#     stopping criterion: RTOL
# Solution found after 120 iterations:
#     objective function f(sol) = 2.507901e+04
#     stopping criterion: RTOL
# Solution found after 137 iterations:
#     objective function f(sol) = 2.175066e+04
#     stopping criterion: RTOL
# Solution found after 134 iterations:
#     objective function f(sol) = 2.262996e+04
#     stopping criterion: RTOL
# Solution found after 174 iterations:
#     objective function f(sol) = 1.662643e+04
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 2.762571e+04
#     stopping criterion: RTOL
# Solution found after 84 iterations:
#     objective function f(sol) = 2.877894e+04
#     stopping criterion: RTOL
# Solution found after 114 iterations:
#     objective function f(sol) = 2.548879e+04
#     stopping criterion: RTOL
# Solution found after 144 iterations:
#     objective function f(sol) = 2.184306e+04
#     stopping criterion: RTOL
# Solution found after 177 iterations:
#     objective function f(sol) = 1.700100e+04
#     stopping criterion: RTOL
# Solution found after 75 iterations:
#     objective function f(sol) = 2.922368e+04
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 2.645937e+04
#     stopping criterion: RTOL
# Solution found after 158 iterations:
#     objective function f(sol) = 2.110552e+04
#     stopping criterion: RTOL
# Solution found after 136 iterations:
#     objective function f(sol) = 2.298964e+04
#     stopping criterion: RTOL
# Solution found after 173 iterations:
#     objective function f(sol) = 1.599462e+04
#     stopping criterion: RTOL
# Solution found after 70 iterations:
#     objective function f(sol) = 3.153622e+04
#     stopping criterion: RTOL
# Solution found after 94 iterations:
#     objective function f(sol) = 2.477348e+04
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 2.404107e+04
#     stopping criterion: RTOL
# Solution found after 144 iterations:
#     objective function f(sol) = 2.082584e+04
#     stopping criterion: RTOL
# Solution found after 162 iterations:
#     objective function f(sol) = 1.887206e+04
#     stopping criterion: RTOL
# Solution found after 77 iterations:
#     objective function f(sol) = 2.984689e+04
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 2.742040e+04
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 2.536479e+04
#     stopping criterion: RTOL
# Solution found after 161 iterations:
#     objective function f(sol) = 1.971735e+04
#     stopping criterion: RTOL
# Solution found after 155 iterations:
#     objective function f(sol) = 2.162532e+04
#     stopping criterion: RTOL
# Solution found after 85 iterations:
#     objective function f(sol) = 3.036699e+04
#     stopping criterion: RTOL
# Solution found after 81 iterations:
#     objective function f(sol) = 2.965055e+04
#     stopping criterion: RTOL
# Solution found after 130 iterations:
#     objective function f(sol) = 2.449912e+04
#     stopping criterion: RTOL
# Solution found after 143 iterations:
#     objective function f(sol) = 2.057447e+04
#     stopping criterion: RTOL
# Solution found after 161 iterations:
#     objective function f(sol) = 1.852193e+04
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 2.877572e+04
#     stopping criterion: RTOL
# Solution found after 102 iterations:
#     objective function f(sol) = 2.772382e+04
#     stopping criterion: RTOL
# Solution found after 119 iterations:
#     objective function f(sol) = 2.458534e+04
#     stopping criterion: RTOL
# Solution found after 156 iterations:
#     objective function f(sol) = 2.019392e+04
#     stopping criterion: RTOL
# Solution found after 172 iterations:
#     objective function f(sol) = 1.679309e+04
#     stopping criterion: RTOL

# %% [markdown]
# Plot both phase transition matrices as images with a colorbar. Make sure to properly name the axes and title the images.

# %%
# Your code here.
pt_dict = {'pt_matrix_1norm': pt_matrix_1norm,
          'pt_matrix_2norm': pt_matrix_2norm}

# %%
fig, ax = plt.subplots(1,2, figsize=(12,10))
lower_bound = np.min([pt_matrix_1norm,pt_matrix_2norm])
upper_bound = np.max([pt_matrix_1norm,pt_matrix_2norm])
for i, key in enumerate(pt_dict.keys()):
    im = ax[i].imshow(pt_dict[key], cmap=cm.Blues, vmin=lower_bound, vmax = upper_bound)
    ax[i].set_title(key,fontdict={'fontsize':14})
    ax[i].set_xlabel('mn ratios index',fontdict={'fontsize':14})
    ax[i].set_ylabel('thresholds index',fontdict={'fontsize':14})

fig.subplots_adjust(bottom=0.1, top=0.9, left=-0.1, right=0.7,
                    wspace=0.15, hspace=0.2)
# add an axes, lower left corner in [0.83, 0.1] measured in figure coordinate with axes width 0.02 and height 0.8
cb_ax = fig.add_axes([0.75, 0.2, 0.03, 0.6])
cbar = fig.colorbar(im, cax=cb_ax)

# %% [markdown]
# ### Question 18
#
# Do the phase transition plots above provide any justification for choosing one $p-$norm interpolation over the other? Why?

# %% [markdown]
# **Your answer here.**
#
# Yes. the p-norm with pt_matrix image most of which blocks are in light color may be the best choice.
