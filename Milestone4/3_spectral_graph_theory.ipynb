# %% [markdown]
# # [NTDS'18] milestone 3: spectral graph theory
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Michaël Defferrard](http://deff.ch), [EPFL LTS2](https://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `<05>`
# * Students: `<Wentao Feng, Yunbei Wang, Yan Fu, Zhaodong Sun>`
# * Dataset: `<Flight route>`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to get familiar with the graph Laplacian and its spectral decomposition.

# %% [markdown]
# ## 0 Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'sklearn'` error when running the below cell, install [scikit-learn](https://scikit-learn.org) with `conda install scikit-learn` (after activating the `ntds_2018` environment).

# %%
import numpy as np
from scipy import sparse
import scipy.sparse.linalg
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import networkx as nx
import pandas as pd
import time

# %% [markdown]
# Let's denote your graph as $\mathcal{G} = (\mathcal{V}, \mathcal{E}, A)$, where $\mathcal{V}$ is the set of nodes, $\mathcal{E}$ is the set of edges, $A \in \mathbb{R}^{N \times N}$ is the (weighted) adjacency matrix, and $N = |\mathcal{V}|$ is the number of nodes.
#
# Import the adjacency matrix $A$ that you constructed in the first milestone.
# (You're allowed to update it between milestones if you want to.)

# %%
adjacency =  np.load('symm_adj.npy')# the adjacency matrix

# %%
weighted_adj = np.load('weighted_adj.npy')
n_nodes =  weighted_adj.shape[0]# the number of nodes in the network

# %% [markdown]
# ## 1 Graph Laplacian

# %% [markdown]
# ### Question 1
#
# From the (weighted) adjacency matrix $A$, compute both the combinatorial (also called unnormalized) and the normalized graph Laplacian matrices.
#
# Note: if your graph is weighted, use the weighted adjacency matrix. If not, use the binary adjacency matrix.
#
# For efficient storage and computation, store these sparse matrices in a [compressed sparse row (CSR) format](https://en.wikipedia.org/wiki/Sparse_matrix#Compressed_sparse_row_.28CSR.2C_CRS_or_Yale_format.29).

# %% [markdown]
# ** For weighted graph we have L = D - W, where L denotes unnormalized Laplacian of graph, D = diag(degree), W is the symmetric weighted matrix.
# **
#
# $$L_{comb} = D - W$$
#
# $$L_{norm} = D^{-1/2}*L*D^{-1/2}$$

# %%
# convert the weighted matrix to a symmetric one
W = weighted_adj + weighted_adj.T

# %%
W_sparse = sparse.csr_matrix(W)

# %%
# calculate the degree for each starting points
# and convert the matrix into array
n_degree = np.sum(W_sparse.A,axis=0)

# %%
np.where(n_degree==0)
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# Since there are no isolated points in our graph we can move on without dropping any point here.

# %%
# Your code here.
D = sparse.diags(n_degree)
laplacian_combinatorial = D - W_sparse

# Your code here.
D_root_inv = sparse.diags(np.sqrt(1/n_degree))
laplacian_normalized =  D_root_inv.dot(laplacian_combinatorial.dot(D_root_inv))

# %%
np.save('laplacian_combinatorial',laplacian_combinatorial.A)

# %%
np.save('laplacian_normalized',laplacian_normalized.A)

# %% [markdown]
# Use one of them as the graph Laplacian $L$ for the rest of the milestone.
# We however encourage you to run the code with both to get a sense of the difference!

# %%
laplacian = laplacian_normalized# Either laplacian_combinatorial or laplacian_normalized.

# %% [markdown]
# ### Question 2
#
# Compute the eigendecomposition of the Laplacian $L = U \Lambda U^\top$, where the columns $u_k \in \mathbb{R}^N$ of $U = [u_1, \dots, u_N] \in \mathbb{R}^{N \times N}$ are the eigenvectors and the diagonal elements $\lambda_k = \Lambda_{kk}$ are the corresponding eigenvalues.
#
# Make sure that the eigenvalues are ordered, i.e., $0 = \lambda_1 \leq \lambda_2 \leq \dots \leq \lambda_N$.

# %%
# Your code here. 
eigenvalues,eigenvectors = np.linalg.eigh(laplacian.A)
assert eigenvectors.shape == (n_nodes, n_nodes)

# %%
U = eigenvectors
lambda_ = np.diag(eigenvalues)
L_reconstruct = np.dot(U,np.dot(lambda_,U.T))

# %%
diff_reconstruct = np.sum(np.abs(laplacian.A-L_reconstruct))
print('The difference of reconstructed Laplacian and the original Laplacian is:',diff_reconstruct)
# Out:
# The difference of reconstructed Laplacian and the original Laplacian is: 4.877251129822872e-10

# %% [markdown]
# Justify your choice of eigensolver.

# %% [markdown]
# **Your answer here.**
#
# We do not use sparse.linalg.eigsh() because it is impossible to calculate all eigenvectors in a matrix for this function.
#
# Here we use `np.linalg.eigh()` which returns the eigenvalues and eigenvectors in **ascending** order of a **symmetric** matrix.
#
# And from the reconstructed Laplacian, we can see that the difference to original Laplacian is near to zero, meaning that the solution of eigenvalues and eigenvactors are correctly chosen.

# %% [markdown]
# ### Question 3
#
# We can write $L = S S^\top$. What is the matrix $S$? What does $S^\top x$, with $x \in \mathbb{R}^N$, compute?

# %% [markdown]
# **Your answer here.**
#
# Matrix $ S $ is incidence matrix with size nodes*edges, where $S(i,j)$=1 means link $j$ starts from node $i$, $S(i,j)$=-1 means link $j$ ends in node $i$, and zero means link $j$ does not link to node $i$.
#
# $(S^\top x)[j] = x[i] - x[k] $  computes gradient of $x$ along edges $j$. And $S^\top x$ computes gradient of $x$ along all edges in the graph separatively.

# %% [markdown]
# ### Question 4
#
# Show that $\lambda_k = \| S^\top u_k \|_2^2$, where $\| \cdot \|_2^2$ denotes the squared Euclidean norm (a.k.a. squared $L^2$ norm).

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# From definition we have:
#
# $$L = S S^\top, L u_k = \lambda_k u_k$$
#
# And we can rewrite $\lambda_k = \| S^\top u_k \|_2^2$ as:
#
# $$\lambda_k = \| S^\top u_k \|_2^2 = u_k^\top S S^\top u_k = u_k^\top L u_k $$
#
# The right hand side $ u_k^\top L u_k = u_k^\top \lambda_k u_k = \lambda_k u_k^\top u_k = \lambda_k$, for $\lambda_k$ is scalar and $u_k^\top u_k=1$.
#
# So we have $\lambda_k = \| S^\top u_k \|_2^2$.

# %% [markdown]
# What does the quantity $\| S^\top x \|_2^2$ tell us about $x$?

# %% [markdown]
# **Your answer here.**
#
# $\| S^\top x \|_2^2$ measures how smooth the graph signal x is.

# %% [markdown]
# ### Question 5
#
# What is the value of $u_0$, both for the combinatorial and normalized Laplacians?

# %% [markdown]
# **Your annswer here.**
#
# Theoretically, for connected graph the eigenvector of first eigenvalue should be a constant vector. As our graph is not a connected one we can see many 'outliers' in $u_0$, because $u_0$ is actually the indicator vectors of the component, and the 'outliers' are points belong to first component.

# %%
eigenvalues_comb,eigenvectors_comb = np.linalg.eigh(laplacian_combinatorial.A)
eigenvalues_norm,eigenvectors_norm = np.linalg.eigh(laplacian_normalized.A)

# %%
i = 0
fig,ax = plt.subplots(1,3,figsize=(20,5))
ax[0].scatter(x=np.arange(0,n_nodes),y=eigenvectors_comb[:,i])
ax[0].set_title('Plot for u0 of combinatorial Laplacians')
ax[1].scatter(x=np.arange(0,n_nodes),y=eigenvectors_norm[:,i])
ax[1].set_title('Plot for u0 of normalized Laplacians')
ax[2].scatter(x=np.arange(0,n_nodes),y=np.dot(D_root_inv.A,eigenvectors_norm[:,i]))
ax[2].set_title('Plot for re-normalized u0 of normalized Laplacians')
for i in range(len(ax)):
    ax[i].set_xlabel('index of elements in u0')
    ax[i].set_ylabel('values in u0')

# %% [markdown]
# ### Question 6
#
# Look at the spectrum of the Laplacian by plotting the eigenvalues.
# Comment on what you observe.

# %%
# Your code here.
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues)
plt.title('The spectrum plot of the Laplacian')
plt.xlabel('Index of eigenvalues')
plt.ylabel('Eigen value')
# Out:
# Text(0,0.5,'Eigen value')

# %% [markdown]
# **Your answer here.**
#
# The eignvalues of graph is the Fourier spectrum value. In this plot, we can see steep growing gap after k-th eigenvalues, which mean our graph may contain k clusters. And it also coincides with the feature of scale-free network.

# %% [markdown]
# How many connected components are there in your graph? Answer using the eigenvalues only.

# %%
# Your code here.
np.where(np.round(eigenvalues,3)==0)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),)

# %% [markdown]
# Is there an upper bound on the eigenvalues, i.e., what is the largest possible eigenvalue? Answer for both the combinatorial and normalized Laplacians.

# %% [markdown]
# **Your answer here.**
#
# There are 8 zero eignvalues in our graph, implying that there are 8 components, which corresponds to previous milestone result.

# %%
temp = laplacian_combinatorial.A
max_theore = np.max(np.sum(abs(temp),axis=1))
print('Theoretical maximum eigenvalue of combinatorial Laplacians is ',max_theore)
# Out:
# Theoretical maximum eigenvalue of combinatorial Laplacians is  3652.0

# %% [markdown]
# Theoretically, the possible largest eigenvalue for normalized Laplacian is 2, denoting bipartite graph.
#
# As for combinatorial Laplacian, according to [Gershgorin circle theorem](https://en.wikipedia.org/wiki/Gershgorin_circle_theorem) the upper bound of maximum eigenvalue should be bounded by the maximum of the largest sum of absolute row, in our case, it is 3652.

# %%
max_norm = max(np.round(eigenvalues_norm,3))
print('The maximum eigenvalue of normalized Laplacians is ',max_norm)
# Out:
# The maximum eigenvalue of normalized Laplacians is  2.0

# %%
max_comb = max(np.round(eigenvalues_comb,3))
print('The maximum eigenvalue of combinatorial Laplacians is ',max_comb)
# Out:
# The maximum eigenvalue of combinatorial Laplacians is  1839.658

# %% [markdown]
# We can check that our eigenvalues are all bellow the theoretical upper bound.

# %% [markdown]
# ## 3 Laplacian eigenmaps
#
# *Laplacian eigenmaps* is a method to embed a graph $\mathcal{G}$ in a $d$-dimensional Euclidean space.
# That is, it associates a vector $z_i \in \mathbb{R}^d$ to every node $v_i \in \mathcal{V}$.
# The graph $\mathcal{G}$ is thus embedded as $Z \in \mathbb{R}^{N \times d}$.

# %% [markdown]
# ### Question 7
#
# What do we use Laplacian eigenmaps for? (Or more generally, graph embeddings.)

# %% [markdown]
# **Your answer here.**
#
# Laplacian eigenmap produces coordinate maps that are smooth functions over the original graph $\mathcal{G}$. We can project our graph $\mathcal{G}$ to a lower dimension $Z \in \mathbb{R}^{N \times d}$ without losing too much information, reducing data dimension to save computation time and easier to find graph features.

# %% [markdown]
# ### Question 8
#
# Embed your graph in $d=2$ dimensions with Laplacian eigenmaps.
# Try with and without re-normalizing the eigenvectors by the degrees, then keep the one your prefer.
#
# **Recompute** the eigenvectors you need with a partial eigendecomposition method for sparse matrices.
# When $k \ll N$ eigenvectors are needed, partial eigendecompositions are much more efficient than complete eigendecompositions.
# A partial eigendecomposition scales as $\Omega(k |\mathcal{E}|$), while a complete eigendecomposition costs $\mathcal{O}(N^3)$ operations.

# %%
# load the largest component index
idx_largest_com = np.load("idx_largest_component.npy")
laplacian_largest = laplacian[idx_largest_com, :]
laplacian_largest = laplacian_largest[:, idx_largest_com]
n_degree_largest = n_degree[idx_largest_com]

# %%
laplacian_largest = np.array(laplacian_largest.todense())

# %%
np.save('laplacian_largest', laplacian_largest)

# %%
# Your code here.
t1 = time.time();
eigenvalues_laplacian_largest,eigenvectors_laplacian_largest = np.linalg.eigh(laplacian_largest) # full eigenvaluedecomposition
print("full eigendecomposition %1.2fs"%(time.time()-t1))
idx2 = (np.argsort(eigenvalues)[1], np.argsort(eigenvalues)[2]) # find the smallest 2 eigenvalues except 0
Z = eigenvectors_laplacian_largest[:,idx2] # corresponding eigenvectors
Z_n = np.dot(np.diag(n_degree_largest**(-1/2)), Z) # renormalize
# Out:
# full eigendecomposition 3.83s

# %%
# recompute eigenvectors
laplacian_largest_sparse = sparse.csr_matrix(laplacian_largest) # convert to csr format
t1 = time.time();
eigenvalues_partial, eigenvectors_partial = sparse.linalg.eigsh(laplacian_largest_sparse, k = 3, which="SA"); # partial eigendecomposition
print("partial (k=3) eigendecomposition %1.2fs"%(time.time()-t1))
Z_recompute = eigenvectors_partial[:,1:3] # corresponding eigenvectors
Z_recompute_n = np.dot(np.diag(n_degree_largest**(-1/2)), Z_recompute) # renormalize
# Out:
# partial (k=3) eigendecomposition 0.07s

# %% [markdown]
# Plot the nodes embedded in 2D. Comment on what you see.

# %%
port_name = np.load("port_name.npy")
port_name = port_name[idx_largest_com]
fig0, ax0 = plt.subplots(nrows=1, ncols=2, figsize = (15,5))
ax0[0].set_xlabel('The first non-zero eigenvalue corresponding eigenvector')
ax0[0].set_ylabel('The second non-zero eigenvalue corresponding eigenvector')
ax0[0].set_title('Spectral Graph Embedding in d=2 (re-normalized)')
ax0[0].scatter(Z_n[:,0], Z_n[:,1]) # re-normalize

ax0[1].set_xlabel('The first non-zero eigenvalue corresponding eigenvector')
ax0[1].set_ylabel('The second non-zero eigenvalue corresponding eigenvector')
ax0[1].set_title('Spectral Graph Embedding in d=2 (without re-normalizing)')
ax0[1].scatter(Z[:,0], Z[:,1]) # without re-normalizing

# %%
airports = pd.read_csv("airports.txt",names = ['Airport_ID','Name','City','Country','IATA','ICAO','Latitude','Longitude',
                                               'Altitude','Timezone','DST','TZ database','Type','Source'])
cluster1 = np.where(Z[:, 0]>0.02)
pn = port_name[cluster1]
airports[['Name', 'City', 'Country']].loc[airports.IATA.isin(pn)]
# Out:
#                            Name              City    Country
# 6            Narsarsuaq Airport      Narssarssuaq  Greenland
# 7       Godthaab / Nuuk Airport          Godthaab  Greenland
# 8         Kangerlussuaq Airport       Sondrestrom  Greenland
# 9                Thule Air Base             Thule  Greenland
# 10             Akureyri Airport          Akureyri    Iceland
# 11          Egilsstaðir Airport       Egilsstadir    Iceland
# 14           Ísafjörður Airport        Isafjordur    Iceland
# 17            Reykjavik Airport         Reykjavik    Iceland
# 3763          Ilulissat Airport         Ilulissat  Greenland
# 3765            Aasiaat Airport           Aasiaat  Greenland
# 4125     Alluitsup Paa Heliport     Alluitsup Paa  Greenland
# 4126    Neerlerit Inaat Airport   Neerlerit Inaat  Greenland
# 4127           Paamiut Heliport           Paamiut  Greenland
# 4129          Qaqortoq Heliport          Qaqortoq  Greenland
# 4130          Maniitsoq Airport         Maniitsoq  Greenland
# 4131        Nanortalik Heliport        Nanortalik  Greenland
# 4132            Narsaq Heliport            Narsaq  Greenland
# 4133            Qaanaaq Airport           Qaanaaq  Greenland
# 4134           Sisimiut Airport          Sisimiut  Greenland
# 4135          Upernavik Airport         Upernavik  Greenland
# 4136            Qaarsut Airport         Uummannaq  Greenland
# 5669          Tasiilaq Heliport      Angmagssalik  Greenland
# 5951  Ittoqqortoormiit Heliport  Ittoqqortoormiit  Greenland
# 6181         Uummannaq Heliport         Uummannaq  Greenland

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# From the plots we can see the two clusters of the re-normalized eigenvectors are more distinguishable, so we keep the re-normalized.
#
# We can see two clusters in the nodes embedded in 2D. The upper right cluster is very small regional airports in Greenland and Iceland. The left cluster is airports from other parts in the world. As from common sense, we know that Greenland and Iceland are away from the continents, so the graph embedding is success in that it coincides with fact.
#
# And we can see that sparse.linalg.eigsh is much faster than np.linalg.eigh.

# %% [markdown]
# ### Question 9

# %% [markdown]
# What does the embedding $Z \in \mathbb{R}^{N \times d}$ preserve?

# %% [markdown]
# **Your answer here.**
#
# $Z \in \mathbb{R}^{N \times d}$ preserves:
# * points connected in $\mathcal{G}$ are still connected in $Z$, and those not connected are still not connected
#
# and,
# * points close in $\mathcal{G}$ are still close to each other in $Z \in \mathbb{R}^{N \times d}$.
#
# Thus we do not lose too much information after graph embedding.

# %% [markdown]
# ## 2 Spectral clustering
#
# *Spectral clustering* is a method to partition a graph into distinct clusters.
# The method associates a feature vector $z_i \in \mathbb{R}^d$ to every node $v_i \in \mathcal{V}$, then runs [$k$-means](https://en.wikipedia.org/wiki/K-means_clustering) in the embedding space $\mathbb{R}^d$ to assign each node $v_i \in \mathcal{V}$ to a cluster $c_j \in \mathcal{C}$, where $k = |\mathcal{C}|$ is the number of desired clusters.

# %% [markdown]
# ### Question 10
#
# Choose $k$ and $d$. How did you get to those numbers?

# %% [markdown]
# **Answer**
# If data has k clear clusters, there will be a steep gap in the Laplacian spectrum after the k-th eigenvalue. So, we choose k such that the gap between $\lambda_k$ and $\lambda_{k+1}$ is distinct. And, we should choose $d = k$ smallest eigen vectors as our feature vectors.

# %% [markdown]
# ### Question 11
#
# 1. Embed your graph in $\mathbb{R}^d$ as $Z \in \mathbb{R}^{N \times d}$.
#    Try with and without re-normalizing the eigenvectors by the degrees, then keep the one your prefer.
# 1. If you want $k=2$ clusters, partition with the Fiedler vector. For $k > 2$ clusters, run $k$-means on $Z$. Don't implement $k$-means, use the `KMeans` class imported from scikit-learn.

# %%
# Compute partial eigen vectors
eigenvalues_cluster, eigenvectors_cluster = sparse.linalg.eigsh(laplacian_largest_sparse, k = 10, which="SA");

# %% [markdown]
# ### Discover $k$

# %%
diff = np.diff(eigenvalues_cluster) # Compute first order difference of eigen values
fig1, ax1 = plt.subplots()
ax1.tick_params(labelsize = 16)
fig1.tight_layout()
ax1.set_title('Plotting top 10 eigenvalues')
ax1.set_xlabel('The index of eigenvalues', fontdict={'fontsize':15})
ax1.set_ylabel('Eigenvalues',fontdict={'fontsize':15})
ax1.scatter(np.arange(eigenvalues_cluster.shape[0]) + 1, eigenvalues_cluster, marker='*')

# %%
fig2, ax2 = plt.subplots()
ax2.tick_params(labelsize = 14)
fig2.tight_layout()
ax2.set_xlabel('The index of eigenvalues', fontdict={'fontsize':15})
ax2.set_ylabel('Difference',fontdict={'fontsize':15})
ax2.set_title('Difference between neighbouring eigenvalue',fontdict={'fontsize':14})
ax2.scatter(np.arange(diff.shape[0])[1:-1] + 2, diff[1:-1])

# %%
k = 2

# %% [markdown]
# **The reason why we choose k = 2:** As we know in spectral clustering, we should choose the k when the gap between $\lambda_{k+1}$ and $\lambda_k$ is relatively large. Here, since the clusters in our graph are not very distinct, it is difficult to find an absolutely good $k$. We have two possible choices: $k=2$ and $k=6$. Considering the graph is the flight route in the world, most of the airports are strongly connected with each other except those who are located in the Arctic area. So, our graph is most likely to have a giant cluster and a small cluster, then we decided to choose k = 2.

# %% [markdown]
# ### Fiedler vector partition - without renormalized

# %%
eig_vector_kmeans = eigenvectors_cluster[:,0:k] # extract eigen vectors corresponding k smallest eigen values

# %%
# calculate clustering labels from normalized clustering
# For Fiedler vector partition we should separate two clusters according to the eigenvector
# using 0 as threshold, cluster 1 correspond to where eigenvector is smaller than 0
# and cluster 2 for eigenvector larger than 0
labels_norm = np.zeros_like(eig_vector_kmeans[:,1])
labels_norm[eig_vector_kmeans[:,1] > 0] = 1 # Normalized partition

# %% [markdown]
# ### Fiedler vector partition - renormalized

# %%
D_root_inv_cluster = D_root_inv.A[idx_largest_com, :][:, idx_largest_com]

# %%
F = D_root_inv_cluster @ eig_vector_kmeans # Compute F vector

# %%
# calculate clustering labels from re-normalized clustering
# using 0 as threshold, cluster 1 correspond to where F vector is smaller than 0
# and cluster 2 for F vector larger than 0
labels_renorm = np.zeros_like(F[:,1])
labels_renorm[F[:,1] > 0] = 1 # Unnormalized clustering

# %% [markdown]
# ### Question 12
#
# Use the computed cluster assignment to reorder the adjacency matrix $A$.
# What do you expect? What do you observe?

# %%
adj_gc = adjacency[idx_largest_com, :][:, idx_largest_com] # largest component adjacency matrix

# %%
# re-order index with normalized partition
reorder_idx_norm = np.argsort(labels_norm, kind = 'quicksort') # reorder index
adj_gc_norm = adj_gc[:, reorder_idx_norm][reorder_idx_norm, :]
# re-order index with re-normalized partition
reorder_idx_renorm = np.argsort(labels_renorm, kind = 'quicksort')
adj_gc_renorm = adj_gc[:, reorder_idx_renorm][reorder_idx_renorm, :]

# %%
fig3,ax3 = plt.subplots(1,3,figsize=(20,5))
ax3[0].spy(adj_gc, markersize=1)
ax3[0].set_title('Not-reodered Laplacians')
ax3[1].spy(adj_gc_norm, markersize=1) 
ax3[1].set_title('Re-ordered Laplacians using normalized clustering')
ax3[2].spy(adj_gc_renorm, markersize=1)
ax3[2].set_title('Re-ordered Laplacians using re-normalized clustering')
for i in range(len(ax)):
    ax3[i].set_xlabel('index of adjacency matrix')

# %% [markdown]
# **Answer** Reordering the adjacency matrix by clustering assignment can gather the points around the diagonal on the spy plot and make the points in the other places more sparse because the links in each cluster are more than the inter-clusters links. The points around the diagonal represent the inner links of clusters and the points that are off the diagonal represents inter-cluster links.
#
# From the plots, we can see that many points gather in the left-upper and right-lower spaces. Moreover, points, which stand for inter clusters link, in other spaces are sparse.

# %% [markdown]
# ### Question 13
#
# If you have ground truth clusters for your dataset, compare the cluster assignment from spectral clustering to the ground truth.
# A simple quantitative measure is to compute the percentage of nodes that have been correctly categorized.
# If you don't have a ground truth, qualitatively assess the quality of the clustering.
#
# Ground truth clusters are the "real clusters".
# For example, the genre of musical tracks in FMA, the category of Wikipedia articles, the spammer status of individuals, etc.
# Look for the `labels` in the [dataset descriptions](https://github.com/mdeff/ntds_2018/tree/master/projects/README.md).

# %%
# reoder airports name and labels by cluster assignment
port_name_norm = port_name[reorder_idx_norm]
port_name_renorm = port_name[reorder_idx_renorm]
labels_norm_ordered = labels_norm[reorder_idx_norm]
labels_unnorm_ordered = labels_renorm[reorder_idx_renorm]

# %%
airports = pd.read_csv("airports.txt",names = ['Airport_ID','Name','City','Country','IATA','ICAO','Latitude','Longitude',
                                               'Altitude','Timezone','DST','TZ database','Type','Source'])

# %%
country_dict_norm = {}
country_dict_unnorm = {}
# initial dictionary to store countries in each cluster
for i in range(k):
    country_dict_norm[i] = []
    country_dict_unnorm[i] = []

# %%
# find the country in each cluster
for idx, j in enumerate(labels_norm_ordered):
    try:
        # try to find the corresponding coutry of airports in each cluster
        country_name = airports.Country[airports.IATA == port_name_norm[idx]].values[0]
    except:
        continue
        
    # if the country has not been tag, add it to the list
    if country_name not in country_dict_norm[j]:
        country_dict_norm[j].append(country_name)

# %%
print('Result of clustering using normalized partition:')
print('cluster0: ', country_dict_norm[0])
print('cluster1: other countries')
# Out:
# Result of clustering using normalized partition:
# cluster0:  ['Greenland', 'Iceland', 'Denmark']
# cluster1: other countries

# %%
# similar procedure with the previous for-loop but using the labels coming from unnormalized partition
for idx, j in enumerate(labels_unnorm_ordered):
    try:
        country_name = airports.Country[airports.IATA == port_name_renorm[idx]].values[0]
    except:
        continue
    if country_name not in country_dict_unnorm[j]:
        country_dict_unnorm[j].append(country_name)

# %%
print('Result of clustering using re-normalized partition:')
print('cluster0: ', country_dict_unnorm[0])
print('cluster1: other countries')
# Out:
# Result of clustering using re-normalized partition:
# cluster0:  ['Greenland', 'Iceland', 'Denmark']
# cluster1: other countries

# %% [markdown]
# **Answer** From the results, we can see some airports in Denmark, Greenland, Iceland are clustered together. Firstly, these three countries(regions) are close geometrically. Moreover, some of their airports are located in the Arctic Circle. So, it is possible that they have some airports that have few routes to the rest of the regions but just connect inside. For this point, we believe the clustering results are reasonable.

# %% [markdown]
# ### Question 14
#
# Plot the cluster assignment (one color per cluster) on the 2D embedding you computed above with Laplacian eigenmaps.

# %%
color = ['#91bfdb','#fc8d59']

# %%
F_embedding = D_root_inv_cluster @ eigenvectors_cluster[:,1:3]

# %%
fig_c, ax_c = plt.subplots()
ax_c.set_title('2-D display on renormalized partition(Preferred)')
for i in range(k):
    ax_c.scatter(F_embedding[np.where(labels_renorm == i),0], F_embedding[np.where(labels_renorm == i),1], c = color[i])

# %%
error_rate_renorm = np.sum(F[np.where(labels_renorm == 0),1] > -0.025) / labels_norm.shape[0]
print('The rate of wrong clustering for renormalized partition:{:2.2%}'.format(error_rate_renorm))
# Out:
# The rate of wrong clustering for renormalized partition:0.15%

# %%
fig_c2, ax_c2 = plt.subplots()
ax_c2.set_title('2-D display on normalized partition')
for i in range(k):
    ax_c2.scatter(eigenvectors_cluster[np.where(labels_norm == i),0], eigenvectors_cluster[np.where(labels_norm == i),1], c = color[i])

# %%
error_rate_norm = np.sum(eigenvectors_cluster[np.where(labels_norm == 0),1] > -0.025) / labels_norm.shape[0]
print('The rate of wrong clustering for normalized partition:{:2.2%}'.format(error_rate_norm))
# Out:
# The rate of wrong clustering for normalized partition:0.15%

# %% [markdown]
# **Comment**
#
# In the two plots, we can see that almost all points are correctly classified into two clusters.
#
# Both re-normalized and normalized partition are doing good, but re-normalized are more distinguishable so we prefer re-normalized partition.

# %% [markdown]
# ### Question 15
#
# Why did we use the eigenvectors of the graph Laplacian as features? Could we use other features for clustering?

# %% [markdown]
# **Answer**
#
# Because for a problem of RatioCut with k clusters, the relaxed optimization problem is:
#
# $min$ $Tr(H'LH)$
# $subject$ $to$ $H'H = I$
#
# And Rayleigh-Ritz theorem tells us that the solution is given by choosing $H$ as the matrix which contains the first $k$ eigenvectors of $L$ as columns.
#
# And the solution is the same for Ncut problem, which is the normalized case.
#
# So we can use eigenvectors of the graph Laplacian as features to find out clusters.
#
# We can also cluster based on the adjacency matrix, and each row is the feature of every node. The number of links between current nodes and other nodes can also represent the connectivity.

# %% [markdown]
# ## Reference
# [1] U. Von Luxburg, “[A Tutorial on Spectral Clustering](https://arxiv.org/abs/0711.0189),” Stat. Comput., vol. 17, no. 4, pp. 395–416, 2007.
