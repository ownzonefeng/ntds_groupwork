# %% [markdown]
# # [NTDS'18] milestone 4: graph signal processing
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Rodrigo Pena](https://people.epfl.ch/254838), [EPFL LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `<05>`
# * Students: `<Wentao Feng, Yunbei Wang, Yan Fu, Zhaodong Sun>`
# * Dataset: `<Flight route>`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to do some Graph Signal Processing (GSP) on the data of your project.
#
# ### A note about plotting
#
# There are several questions in this milestone that ask you to plot a signal on your network.
# There are several ways from which you could approach it.
# In all cases, compute the position of the nodes a single time at the beginning, as this is likely to be a costly operation.
# Using a single layout for all the graph plots will also make it easier to compare the plots.
# Indeed, the only thing changing between plots is the signal displayed.
# You can represent the features/labels lying on the graph via node **colors**.
# To do so, make sure to have a consistent color map throughout and remember to display a colorbar and scale in all plots, so that we can tell what numbers the colors represent.
#
# * An option is to use the **Laplacian eigenmaps** that you have seen in the previous milestone to embed your graph on the plane. For example:
#   ```
#   from matplotlib import pyplot as plt
#   plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], c=signal, alpha=0.5)
#   plt.colorbar()
#   ```
# * Another option is to use the plotting capabilities of **[NetworkX](https://networkx.github.io)**.
#   See the documentation of its [drawing methods](https://networkx.github.io/documentation/stable/reference/drawing.html).
#   For example:
#   ```
#   import networkx as nx
#   graph = nx.from_scipy_sparse_matrix(adjacency)
#   coords = nx.spring_layout(graph)  # Force-directed layout.
#   coords = eigenvectors[:, 1:3]  # Laplacian eigenmaps.
#   nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
#   nx.draw_networkx_edges(graph, coords, alpha=0.3)
#   ```
# * Another option is to use the plotting capabilities of the **[PyGSP](https://github.com/epfl-lts2/pygsp)**, a Python package for Graph Signal Processing.
#   **Note that your are forbidden to use the PyGSP for anything else than plotting.**
#   See the documentation of its [plotting utilities](https://pygsp.readthedocs.io/en/stable/reference/plotting.html).
#   For example:
#   ```
#   import pygsp as pg
#   graph = pg.graphs.Graph(adjacency)
#   graph.set_coordinates('spring')  # Force-directed layout.
#   graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps.
#   graph.plot_signal(signal)
#   ```
# * Yet another option is to save your graph on disk, use **[Gephi](https://gephi.org)** externally, to visualize the graph, save the graph with the Gephi coordinates and finally load the nodes coordinates back into the notebook.
#
# We encourage you to try all the above methods before making your choice. Then be consistent and use only one throughout the milestone.
# NetworkX and PyGSP should already be installed in your environement. If that's not the case, install with `conda install networkx pygsp` (after activating the `ntds_2018` environment).

# %% [markdown]
# ## 0 - Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'pyunlocbox'` error when running the below cell, install the [pyunlocbox](https://github.com/epfl-lts2/pyunlocbox) with `conda install pyunlocbox` (after activating the `ntds_2018` environment).

# %%
import numpy as np
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from pyunlocbox import functions, solvers

# %%
import networkx as nx
import pandas as pd
from matplotlib import cm

# %% [markdown]
# For this milestone, all we will need is a set of features/labels for each of the nodes on the network, as well as the Laplacian, $L,$ and Gradient, $\nabla_G,$ matrices that you have computed for your network while working on milestone 3.
#
# Import those objects in the cell below (or recompute the Laplacian and Gradient from your stored adjacency matrix, if you wish).
#
# _Note_: If your features/labels are not floating-point numbers, please convert them. For example, if your data has labels "cat" and "dog" for nodes that represent cats or dogs, respectively, you may assign the number `1.0` for the label "cat" and the number `-1.0` for the label "dog".

# %%
# load weighted adjacency matrix
adjacency =  np.load('symm_adj.npy')
weighted_adj = np.load('weighted_adj.npy')
W = weighted_adj + weighted_adj.T

# %%
idx_GC = np.load("idx_largest_component.npy")
GC = W[idx_GC, :]
GC = GC[:, idx_GC]
GC_sparse = sparse.csr_matrix(GC)
W_GC = W[idx_GC, :][:, idx_GC] # get the adjacency matrix of the largest component

# %%
n_degree = np.sum(GC,axis=0)
D = sparse.diags(n_degree)
laplacian_combinatorial = D - GC_sparse

D_root_inv = sparse.diags(np.sqrt(1/n_degree))
laplacian_normalized =  D_root_inv.dot(laplacian_combinatorial.dot(D_root_inv)) # compute the laplacian

# %%
PortGeo = pd.read_csv('PortGeo.csv') # DataFrame containing node information

# %%
idx_hub = np.where(n_degree>1000) # hub index

# %%
PortGeo.set_index('index').loc[idx_GC[idx_hub]] # selected hubs are shown below
# Out:
#       Port IATA  ICAO   Latitude   Longitude  \
# index
# 458    CDG  CDG  LFPG  49.012798    2.550000
# 1588   LHR  LHR  EGLL  51.470600   -0.461941
# 2144   PEK  PEK  ZBAA  40.080101  116.584999
# 163    ATL  ATL  KATL  33.636700  -84.428101
# 2075   ORD  ORD  KORD  41.978600  -87.904800
#
#                                                    Name         Country
# index
# 458             Charles de Gaulle International Airport          France
# 1588                            London Heathrow Airport  United Kingdom
# 2144              Beijing Capital International Airport           China
# 163    Hartsfield Jackson Atlanta International Airport   United States
# 2075               Chicago O'Hare International Airport   United States

# %%
# label: nodes connected to the hubs are set to one else zero.
n_nodes = GC.shape[0]
label = np.zeros(n_nodes)
for i in idx_hub[0]:
    label += GC[:,i]
label[label>0]=1

# %%
# find latitude and longtitude corresponding to the adjacency matrix
latitude = np.zeros(n_nodes)
longtitude = np.zeros(n_nodes)
for i in range(len(GC)):
    if len(PortGeo.loc[PortGeo['index']==idx_GC[i]].Latitude.get_values()):
        latitude[i] = PortGeo.loc[PortGeo['index']==idx_GC[i]].Latitude.get_values()[0]
        longtitude[i] = PortGeo.loc[PortGeo['index']==idx_GC[i]].Longitude.get_values()[0]

# %%
# compute the gradient.
edge_idx = 0
n_edges = np.sum(GC > 0) / 2
gradient = np.zeros([int(n_edges), int(n_nodes)])
for i in range(n_nodes):
    for j in range(i + 1, n_nodes):
        if W_GC[i, j] > 0:
            gradient[edge_idx, i] = -np.sqrt(W_GC[i, j]) * (label[j] - label[i]) # according to the formula grad f[i,j] = sqrt(Wij)(f(i) - f(j))
            gradient[edge_idx, j] = -gradient[edge_idx, i]
            edge_idx += 1

# %%
laplacian = laplacian_combinatorial
labels = label
n_nodes = GC.shape[0]

# %% [markdown]
# **ANSWER**
#
# As shown above, we decide to choose the airports linked to top-5 busiest airports as label 1, and the rest airports not-linked to these 5 airport as label 0.

# %% [markdown]
# ## 1 - Graph Fourier Transform
#
# In this section we will observe how your feature/label vector looks like in the "Graph Fourier" domain.

# %% [markdown]
# ### Question 1
#
# Compute the Fourier basis vectors and the Laplacian eigenvalues. Make sure to order those from smaller to larger, $\lambda_0 \leq \lambda_1 \leq \dots \leq \lambda_{N-1},$ and use the same ordering for the Fourier basis vectors.

# %% [markdown]
# Plot the first 3 and the last Fourier basis vectors as signals on your graph. Clearly indicate which plot belongs to which basis vector.

# %%
e,U = np.linalg.eigh(laplacian.A)

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(U[:,0],label='The First Eigenvector')
ax.plot(U[:,1],label='The Second Eigenvector')
ax.plot(U[:,2],label='The Third Eigenvector')
ax.plot(U[:,-1],label='The Last Eigenvector')
ax.legend()
ax.set_title('Plot for eigenvector')
ax.set_xlabel('Vertex Index')
# Out:
# Text(0.5,0,'Vertex Index')

# %% [markdown]
# ### Question 2
#
# What can you observe in terms of local variations when comparing the basis vectors corresponding to the smallest eigenvalues to those corresponding to the largest eigenvalue? How would this justify the interpretation of the eigenvalues as "graph frequencies"?

# %% [markdown]
# **Your answer here.**
#
# The graph Laplacian eigenvectors associated with low eigenvalues vary slowly across the graph while eigenvectors corresponding to larger eigenvalues have more oscillations.
#
# We can also observe the traditional Fourier basis vectors $exp(j2\pi ft)$ which have the same property. With larger $f$, the basis vector oscillates more rapidly. The basis vector is constant when $f=0$, which is similar to the first eigenvector and first zero eigenvalue. Therefore, we can see some similarities between eigenvalues and the frequencies.

# %% [markdown]
# ### Question 3
#
# Implement a function that returns the Graph Fourier Transform (GFT) of a given vector $x \in \mathbb{R}^{N},$ with respect to your graph, and a function that computes the corresponding inverse GFT (iGFT).

# %%
def GFT(x):
    return U.T.dot(x)# Your code here.

def iGFT(x): 
    return U.dot(x)# Your code here.

# %% [markdown]
# ### Question 4
#
# Plot your feature/label vector as a signal on your graph

# %%
def G_edgelist(adj): # function to return the edges of the graph for the adjacency matrix (for plot)
    x,y = np.nonzero(adj)
    G = nx.Graph()
    for i in range(len(x)):
        G.add_edge(x[i],y[i],weight=adj[x[i]][y[i]])
    return G.edges()

# %%
def G_pos(x,y,n_nodes): # function to return the position(latitiude and longtitude) of  each node (for plot)
    pos_dic = {}
    for i in range(n_nodes):
        pos_dic[i] = x[i],y[i]
    return pos_dic

# %%
top5 = np.zeros_like(GC)
top5[:,idx_hub] = GC[:,idx_hub]
top5[idx_hub,:] =GC[idx_hub,:] # only keep the weights of nodes conneted to the top-5 hub

# %%
edgetop5 = G_edgelist(top5) # return the edges linked to the top-5 hubs
pos = G_pos(x=longtitude,y=latitude,n_nodes=n_nodes) # return the positions (latitiude and longtitude) of all nodes
G=nx.from_numpy_array(GC)

# %%
plt.figure(figsize=(15*1.8,15))

nx.draw(G, pos=pos,node_size=30,width=0.1,node_color=labels,cmap='RdYlBu',edgelist=edgetop5)
plt.title('Plot for airports connected to the top-5 busiest airports',fontsize='30')
# Out:
# Text(0.5,1,'Plot for airports connected to the top-5 busiest airports')

# %% [markdown]
# Plot the absolute values of the GFT of your feature/label signal as a function of the graph eigenvalues. Make sure to add a marker indicating the position of each graph eigenvalue, and remember to properly name the axes.

# %%
plt.scatter(x=e, y=abs(GFT(labels)).ravel()/np.max(abs(GFT(labels))),s=10)
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.title('Label in Spectral Domain with GFT')
plt.grid()

# %% [markdown]
# ### Question 5
#
# Discuss the behavior of the GFT that you plotted in the last question via comparing the plot of your label signal and those of the Fourier basis of Question 1. Would you consider your labels a "low-pass" or "high-pass" signal, or yet something else entirely?

# %% [markdown]
# **Your answer here.**
#
# It is a low-pass signal.

# %% [markdown]
# ## 2 - Filtering on graphs
#
# In this section we will check how filtered Dirac impulses diffuse on your graph.

# %% [markdown]
# ### Question 6
#
# Implement the following three filter kernels and the graph filtering operation.
#
# - The **heat kernel** is supposed to take in a vector of eigenvalues `e` and a parameter `t` and output a vector of evaluations of the heat kernel at those eigenvalues (see the course slides for help).
# - The **inverse filter** kernel is supposed to take in a vector of eigenvalues `e` and a parameter `t` and implement spectrally the  filter defined in the node domain by $f_{out}  = (I + t L)^{-1} f_{in},$ where $f_{in}, f_{out} \in \mathbb{R}^{N}$ are, repectively, the input and output signals to the filter.
# - The **rectangle kernel** takes in a vector of eigenvalues `e` and parameters `l_min` and `l_max` and returns `1.0` at coordinates satisfying $(e[l] \geq l_{min}) \wedge (e[l] \leq l_{max}),$ and `0.0` otherwise.
# - The **graph filtering** operation takes a graph signal $x \in \mathbb{R}^{N}$, a spectral graph `kernel` and a set of keyworded variables, and returns the corresponding filtered signal.
#     - _Hint:_ Remember that you have implemented the `GFT` and `iGFT` operations in Question 3.
#     - The `**kwargs` is a placeholder to collect supplementary pairs of keyword-values that are not known by the implementation before execution time.
#       The `kwargs` variable is a dictionary whose keyes and values are the parameter names and values.
#       This is useful to allow both `graph_filter(x, heat_kernel, tau=1.0)` and `graph_filter(x, rectangle_kernel, lambda_min=0.0, lambda_max=1.0)` to be valid calls from the same implementation.
#       One can then defer the keyword-value assignment to the `kernel` call: `foo = kernel(bar, **kwargs)`.

# %%
def heat_kernel(e, t):
    return np.diag(np.exp(-t*e))

def inverse_kernel(e, t):
    return np.diag(1/(1+t*e))

def rectangle_kernel(e, l_min, l_max):
    return np.diag((e>=l_min)&(e<=l_max).astype(int))

def graph_filter(x, kernel, **kwargs):
    return iGFT(kernel(**kwargs)@GFT(x))

# %% [markdown]
# ### Question 7
#
# Plot all three filter kernels in the **spectral domain**. Remember to properly name the axes and title the plots. Choose filter parameters that best approximate the behavior of the GFT of your feature/label signal (as seen in Question 4).

# %%
# Your code here.
plt.figure(figsize=(8*1.6,8))

test_label = labels

plt.subplot(221)
plt.scatter(x=e, y=abs(GFT(test_label)).ravel()/np.max(abs(GFT(test_label))),s=5)
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.title('Label in Spectral Domain with GFT')
plt.grid()

plt.subplot(222)
plt.plot(e,np.diag(heat_kernel(e=e,t=0.05)),'-')
plt.title('Heat Kernel in Spectral Domain')
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.grid()

plt.subplot(223)
plt.plot(e,np.diag(inverse_kernel(e=e,t=0.15)),'-')
plt.title('Inverse Kernel in Spectral Domain')
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.grid()

plt.subplot(224)
plt.plot(e,np.diag(rectangle_kernel(e=e,l_min=250,l_max=1000)),'-')
plt.title('Rectangular Kernel in Spectral Domain')
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Value')
plt.grid()

plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### Question 8
#
# Consider two Dirac impulses arbitrarily placed on your graph. Plot their filtered versions by the three filter kernels implemented in Question 6.

# %%
Dirac_impulse = np.zeros(n_nodes)
idx_Dirac = idx_hub[0][[2,3]]
Dirac_impulse[idx_Dirac]=1

# %%
Dirac = np.zeros_like(GC)
Dirac[:,idx_Dirac] = GC[:,idx_Dirac]
Dirac[idx_Dirac,:] = GC[idx_Dirac,:]
edgeDirac = G_edgelist(Dirac) # return edges connected to the selected two nodes

# %%
test_label = Dirac_impulse
test_label = test_label.reshape(len(test_label),1)

# %%
plt.figure(figsize=(12*1.6,12))

kernel = heat_kernel
heat_taus = np.array([0.01,0.05,0.5,1])

for i in range(len(heat_taus)): # iterate the parameter tau in heat kernal to subplot
    plt.subplot(2,2,i+1)
    heat = np.diag(heat_kernel(e=e,t=heat_taus[i]))
    heat = heat.reshape(len(heat),1)
    nx.draw(G, pos=pos,node_size=10, node_color=iGFT(heat*GFT(test_label)).ravel(),width=0,cmap='Blues')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('Filtered by Heat Kernel with tau = %0.3f'%heat_taus[i])

# %%
plt.figure(figsize=(12*1.6,12))

kernel = inverse_kernel
inverse_taus = np.array([0.5,1,3,5])

for i in range(len(inverse_taus)): # iterate the parameter t in inverse kernal to subplot
    plt.subplot(2,2,i+1)
    inverse = np.diag(inverse_kernel(e=e,t=inverse_taus[i]))
    inverse = inverse.reshape(len(inverse),1)
    nx.draw(G, pos=pos,node_size=10, node_color=iGFT(inverse*GFT(test_label)).ravel(),width=0,cmap='Blues')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('Filtered by Inverse Kernel with tau = %0.3f'%inverse_taus[i])

# %%
plt.figure(figsize=(12*1.6,12))

kernel = rectangle_kernel
l_maxs = np.array([200,100,5,1])

for i in range(len(heat_taus)): # iterate the parameter l_max in rectangular kernal to subplot
    plt.subplot(2,2,i+1)
    rec = np.diag(rectangle_kernel(e=e,l_min=-0.001, l_max=l_maxs[i]))
    rec = rec.reshape(len(rec),1)
    nx.draw(G, pos=pos,node_size=10, node_color=iGFT(rec*GFT(test_label)).ravel(),width=0,cmap='Blues')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('Filtered by Rectangular Kernel with l_max = %0.3f'%l_maxs[i])

# %% [markdown]
# Comment on the "diffusion" of the Diracs induced by the filters. What does it say about the "communication" of information across your network? Relate that to the **network connectivity** measures that you analyzed during the previous milestones.

# %% [markdown]
# **Your answer here.**
#
# The three filters above are all low-frequency filters and after filtering, the energy of Diracs signal is averaged and spread to its neighbour airports. First it diffuses to its nearest airports, and with time goes by (in our case, with the cutoff frequency of filters increasing) if diffuses to worldwide airports. The more remote and less links one airport is, the slower Diracs signal diffuses to it.

# %% [markdown]
# ## 3 - De-noising
#
# In this section we will add some centered Gaussian noise to your feature/label signal and attempt to recover it.

# %% [markdown]
# ### Question 9
#
# In the cell below, set the noise variance $\sigma^2$ by making sure that the signal-to-noise ratio $SNR = \frac{\operatorname{Var}(\text{labels})}{\sigma^2}$ is about  $1.5$.
#
# _Note:_ Actually, you might want to play with the noise variance here and set it to different values and see how the denoising filters behave.

# %%
SNR =0.5

noise_variance = np.var(labels)/SNR# Your code here.
noisy_measurements = labels.ravel() + np.sqrt(noise_variance) * np.random.randn(n_nodes)
noisy_measurements = noisy_measurements.reshape(noisy_measurements.shape[0],1)

# %% [markdown]
# ### Question 10
#
# In the denoising setting, a common graph signal processing assumption is that the signal $z$ that we want to recover is "smooth", in the sense that $\|\nabla_G z\|_2 = \sqrt{z^{\top} L z}$ is small, while remaining "close" to the measurements that we start with. This leads to denoising by solving the following optimization problem:
#
# $$
# z^\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \|z - y\|_2^2 + \gamma z^{\top} L z,
# $$
#
# where $y \in \mathbb{R}^{N}$ is the vector of noisy measurements.
#
# Derive the close form solution to this problem giving $z^\star$ as a function of $y$, $\gamma$ and $L$. Does this solution correspond to any graph filtering operation that you know?

# %% [markdown]
# **Your answer here.**
#
# Compute the gradient of optimizationproblem and set the gradient to zero. Because we can easily find out that the optimization problem is convex, thus $z^\star$ making gradient to zero is the solution.
#
# $$z^\star = (I + \gamma L)^{-1} y$$
#
# It has a similar form to inverse filter.

# %% [markdown]
# ### Question 11
#
# Now, denoise the noisy measurements by passing them through the filters that you implemented in Question 6. Choose the filter parameters based on the behavior of the GFT of your original label signal (this is the prior knowledge that you input to the problem).

# %%
f_in = noisy_measurements
heat_denoise = graph_filter(x=f_in, kernel=heat_kernel, e=e,t = 0.05)

inverse_denoise = graph_filter(x=f_in, kernel=inverse_kernel, e=e,t = 0.15)

rec_denoise = graph_filter(x=f_in, kernel=rectangle_kernel, e=e,l_min=-0.001,l_max=50)

# %%
plt.figure(figsize=(15,10))
xx = np.arange(label.shape[0])

plt.subplot(321)
plt.scatter(xx, labels,s=1)
plt.title('Origin signal')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(322)
plt.scatter(xx, f_in, s=1)
plt.title('Noisy signal')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(323)
plt.scatter(xx, heat_denoise, s=1)
plt.title('Noise denoised by heat filter')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(324)
plt.scatter(xx, inverse_denoise, s=1)
plt.title('Noise denoised by inverse filter')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(325)
plt.scatter(xx, rec_denoise, s=1)
plt.title('Noise denoised by rectangle filter')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# Plot, on your graph, the original label signal, the noisy measurements, and the three denoised version obtained above. Report on each plot the value of the corresponding relative error
# $$
# \text{rel-err} = \frac{\|\text{labels} - z \|_2}{\|\text{labels}\|_2},
# $$
# where $z$ is the plotted signal.

# %%
# Your code here.
def rel_err(label,z):
    return np.linalg.norm((label-z.ravel()))/np.linalg.norm(label)

# %%
print('relative error of the noisy signal: %1.2f'%rel_err(labels,noisy_measurements))
# Out:
# relative error of the noisy signal: 1.29

# %%
print('relative error of the signal denoised by heat kernel: %1.2f'%rel_err(labels,heat_denoise))
# Out:
# relative error of the signal denoised by heat kernel: 1.02

# %%
print('relative error of the signal denoised by inverse kernel: %1.2f'%rel_err(labels,inverse_denoise))
# Out:
# relative error of the signal denoised by inverse kernel: 0.92

# %%
print('relative error of the signal denoised by rectangular kernel: %1.2f'%rel_err(labels,rec_denoise))
# Out:
# relative error of the signal denoised by rectangular kernel: 1.25

# %% [markdown]
# Finally, overlay on the same plot the GFT of all five signals above.

# %%
# Your code here.
plt.figure(figsize=(15,10))
plt.subplot(321)
plt.plot(e,abs(GFT(labels)))
plt.title('Origin signal in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(322)
plt.plot(e,abs(GFT(f_in)))
plt.title('Noisy signal in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(323)
plt.plot(e,abs(GFT(heat_denoise)))
plt.title('Noise denoised by heat filter in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(324)
plt.plot(e,abs(GFT(inverse_denoise)))
plt.title('Noise denoised by inverse filter in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplot(325)
plt.plot(e,abs(GFT(rec_denoise)))
plt.title('Noise denoised by rectangle filter in spetral domain')
plt.xlabel('Vertex Index')
plt.ylabel('Signal Strength')

plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### Question 12
#
# Comment on which denoised version seems to best match the original label signal. What is the underlying assumption behind the three filtering approaches? Do you think it holds for your label signal? Why?

# %% [markdown]
# **Your answer here.**
#
# From plot and $rel-err$ we know the heat filter and inverse filter are doing the best, which coincides to the result from Question 10.
#
# From question 7 we can see all filters are low frequency filter(rectangle filter can be modified into a band-pass filter but it does not hurt the following conclusion), they assume that the noise clearly has different frequency from the origin signal, that's why they can denoise.
#
# However, we are using Gaussian noise and this noise is uniformly distributed in spectral domain and our signal has a relatively large band width. These lowpass filters can remove the high frequency component of the noise but keep the low frequency component. If we choose a lowpass filter with small passband, most of the noise can be removed but the spectrum of the original signal will be distorted. On the other hand, if we use a lowpass filter with large passband, the spectrum of the signal won't be destroyed but most of the noise still remains. So we can see that all filters are not doing very well in denoising.

# %% [markdown]
# ## 4 - Transductive learning
#
# It is often the case in large networks that we can only afford to query properties/labels on a small subset of nodes. Nonetheless, if the underlying labels signal is "regular" enough, we might still be able to recover a good approximation of it by solving an offline variational problem, with constraints on the values of the measured nodes.
#
# In this section, we will be interested in solving such transductive learning problems by minimizing a (semi-) p-norm of the graph gradient applied to the signal of interest:
#
# $$
# \text{arg} \, \underset{z|_S = y}{\min} \|\nabla_G z\|_p^p,
# $$
#
# where $S$ is the set of measured nodes.
#
# In English, we can say that we are looking for solutions with small "aggregated local variations", as measured by $\|\nabla_G z\|_p^p = \sum_{i=1}^{n} \sum_{j=1}^{n} \left( \sqrt{W_{ij}} |z[i] - z[j]| \right)^p,$ while satisfying the measurement constraints $z[i] = y[i]$ for $i \in S.$
#
# We will work with two cases, according to the choices $p=1$ or $p=2.$ For $p=1,$ the problem is known as "interpolation by graph total-variation minimization," whereas for $p=2$ it is sometimes called "interpolation by Tikhonov regularization".
#
# In order to solve these variational problems with the black-box solver provided to you, you will use the [pyunlocbox](https://pyunlocbox.readthedocs.io). This toolbox implements iterative solvers based on so-called ["proximal-splitting"](https://en.wikipedia.org/wiki/Proximal_gradient_method) methods.

# %% [markdown]
# ### Question 13
#
# Throughout this section, we will consider only a binarized version of your label signal. If your variable `labels` currently has values other than $\{-1, 1\},$ threshold them so that those are the only values taken in this vector. This can be done for example by choosing a number $t \in \mathbb{R}$ and then setting $\text{labels_bin}[i] = 1$ if $\text{labels}[i] \geq t$ and $\text{labels_bin}[i] = 0$ otherwise.

# %%
labels_bin = np.copy(labels) # binarized labels
labels_bin = labels_bin * 2 - 1

# %% [markdown]
# Now, subsample this binarized label signal by $70\%$ by choosing, uniformly at random, $30\%$ of the nodes whose labels we will keep.
#
# You will do this by computing a "measurement mask" vector `w` with `1.0`'s at the measured coordinates, and $0.0$'s otherwise.

# %%
mn_ratio = 0.3
m = int(mn_ratio * n_nodes)  # Number of measurements.
w = np.ones_like(labels_bin)
mask_idx = np.random.permutation(n_nodes)[0:(n_nodes - m)]
w[mask_idx] = 0

# %% [markdown]
# Plot the subsampled signal on the graph. _Hint:_ you might want to set to `numpy.nan` the values of the un-measured nodes for a cleaner plot.

# %%
# Your code here.
labels_bin_plt = np.copy(labels_bin)
labels_bin_plt[mask_idx] = np.nan

# %%
fig, ax = plt.subplots(1,2,figsize = [18,6])
ax[0].scatter(np.arange(n_nodes), labels_bin,marker='|')
ax[0].set_title('Original signal', fontdict={'fontsize':15})
ax[1].scatter(np.arange(n_nodes), labels_bin_plt,marker='|')
ax[1].set_title('Subsampled signal', fontdict={'fontsize':15})
for i in range(len(ax)):
    ax[i].tick_params(labelsize = 16)
    ax[i].set_xlabel('Nodes',fontdict={'fontsize':15})
    ax[i].set_ylabel('Labels',fontdict={'fontsize':15})

# %% [markdown]
# ### Interlude
#
# For the solution of the variational problems you can use the following function as a "black-box".
#
# You will just need to provide a `gradient` matrix (which you should already have from Section 0), and an orthogonal projection operator `P` onto the span of the measured coordinates (made precise in the next question).

# %%
def graph_pnorm_interpolation(gradient, P, x0=None, p=1., **kwargs):
    r"""
    Solve an interpolation problem via gradient p-norm minimization.

    A signal :math:`x` is estimated from its measurements :math:`y = A(x)` by solving
    :math:`\text{arg}\underset{z \in \mathbb{R}^n}{\min}
    \| \nabla_G z \|_p^p \text{ subject to } Az = y` 
    via a primal-dual, forward-backward-forward algorithm.

    Parameters
    ----------
    gradient : array_like
        A matrix representing the graph gradient operator
    P : callable
        Orthogonal projection operator mapping points in :math:`z \in \mathbb{R}^n` 
        onto the set satisfying :math:`A P(z) = A z`.
    x0 : array_like, optional
        Initial point of the iteration. Must be of dimension n.
        (Default is `numpy.random.randn(n)`)
    p : {1., 2.}
    kwargs :
        Additional solver parameters, such as maximum number of iterations
        (maxit), relative tolerance on the objective (rtol), and verbosity
        level (verbosity). See :func:`pyunlocbox.solvers.solve` for the full
        list of options.

    Returns
    -------
    x : array_like
        The solution to the optimization problem.

    """
    
    grad = lambda z: gradient.dot(z)
    div = lambda z: gradient.transpose().dot(z)

    # Indicator function of the set satisfying :math:`y = A(z)`
    f = functions.func()
    f._eval = lambda z: 0
    f._prox = lambda z, gamma: P(z)

    # :math:`\ell_1` norm of the dual variable :math:`d = \nabla_G z`
    g = functions.func()
    g._eval = lambda z: np.sum(np.abs(grad(z)))
    g._prox = lambda d, gamma: functions._soft_threshold(d, gamma)

    # :math:`\ell_2` norm of the gradient (for the smooth case)
    h = functions.norm_l2(A=grad, At=div)

    stepsize = (0.9 / (1. + scipy.sparse.linalg.norm(gradient, ord='fro'))) ** p

    solver = solvers.mlfbf(L=grad, Lt=div, step=stepsize)

    if p == 1.:
        problem = solvers.solve([f, g, functions.dummy()], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    if p == 2.:
        problem = solvers.solve([f, functions.dummy(), h], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    else:
        return x0

# %% [markdown]
# ### Question 14
#
# During the iterations of the algorithm used for solving the variational problem, we have to make sure that the labels at the measured nodes stay the same. We will do this by means of an operator `P` which, given a vector $a \in \mathbb{R}^{N},$ returns another vector $b \in \mathbb{R}^{N}$ satisfying $b[i] = \text{labels_bin}[i]$ for every node $i$ in the set $S$ of known labels, and $b[i] = a[i]$ otherwise. Write in the cell below the function for this orthogonal projection operator `P`.
#
# _Hint:_ remember you have already computed the mask `w`.

# %%
def P(a):
    b = a
    b[np.where(w == 1)] = labels_bin[np.where(w == 1)]
    return b

# %% [markdown]
# ### Question 15
#
# Solve the variational problems for $p = 1$ and $p = 2$. Record the solution for the $1-$norm minimization under `sol_1norm_min` and the one for $2-$norm minimization under `sol_2norm_min`.
#
# Compute also binarized versions of these solutions by thresholding the values with respect to $0$, that is, non-negative values become `1.0`, while negative values become `-1.0`. Store those binarized versions under `sol_1norm_bin` and `sol_2norm_bin`, respectively.

# %%
gradient = sparse.csr_matrix(gradient)
x0 = np.random.randn(n_nodes)
x0_bin = np.random.randn(n_nodes)

# %%
sol_1norm_min = graph_pnorm_interpolation(gradient, P, x0 = x0, p=1., maxit = 3000)

sol_2norm_min = graph_pnorm_interpolation(gradient, P, x0 = x0, p=2., maxit = 3000)

threshold = 0

sol_1norm_bin = graph_pnorm_interpolation(gradient, P, x0 = x0_bin, p=1., maxit = 3000)
sol_1norm_bin[sol_1norm_bin >= 0] = 1
sol_1norm_bin[sol_1norm_bin < 0] = -1

sol_2norm_bin = graph_pnorm_interpolation(gradient, P, x0 = x0_bin, p=2., maxit = 3000)
sol_2norm_bin[sol_2norm_bin >= 0] = 1
sol_2norm_bin[sol_2norm_bin < 0] = -1
# Out:
# Solution found after 1020 iterations:
#     objective function f(sol) = 6.810541e+05
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 3.196176e+08
#     stopping criterion: RTOL
# Solution found after 1021 iterations:
#     objective function f(sol) = 6.872593e+05
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 3.406042e+04
#     stopping criterion: RTOL

# %%
rel_err_comp = {'sol_1norm_min': rel_err(label, sol_1norm_min),
                'sol_2norm_min': rel_err(label, sol_2norm_min),
                'sol_1norm_bin': rel_err(labels_bin, sol_1norm_bin),
                'sol_2norm_bin': rel_err(labels_bin, sol_2norm_bin),}

# %%
for key in rel_err_comp.keys():
    print(('relative error for ' + key + ' is {:2.2f}').format(rel_err_comp[key]))
# Out:
# relative error for sol_1norm_min is 60.44
# relative error for sol_2norm_min is 60.44
# relative error for sol_1norm_bin is 1.55
# relative error for sol_2norm_bin is 1.55

# %%
fig, ax = plt.subplots(3,2,figsize=(12,10))
ax[0,0].remove()
ax[0,1].remove()
axs = fig.add_subplot(311)
x = np.arange(n_nodes)
axs.scatter(x, labels_bin, marker='|')
axs.set_xlabel('Nodes',fontdict={'fontsize':14})
axs.set_ylabel('Labels',fontdict={'fontsize':14})
axs.set_title('Original binarized signal',fontdict={'fontsize':14})
axs.tick_params(labelsize = 12)
for i, key in enumerate(rel_err_comp.keys()):
    exec('%s = %s' % ('temp', key))
    loc = [int(i / 2) + 1, i % 2]
    ax[loc[0], loc[1]].tick_params(labelsize = 12)
    ax[loc[0], loc[1]].scatter(x, temp, marker='|')
    ax[loc[0], loc[1]].set_xlabel('Nodes',fontdict={'fontsize':14})
    ax[loc[0], loc[1]].set_ylabel('Labels',fontdict={'fontsize':14})
    ax[loc[0], loc[1]].set_title(key, fontdict={'fontsize':14})
fig.tight_layout()

# %% [markdown]
# Plot, on your graph, the original `labels_bin` signal, as well as the solutions to the variational problems (both binarized and otherwise). Indicate on each plot the value of the relative error $\text{rel-err} = \frac{\|\text{labels_bin} - z\|_2}{\|\text{labels_bin}\|_2}$, where $z$ is the signal in the corresponding plot.

# %% [markdown]
# ### Question 16
#
# Now that you have got a feeling for the sort of solutions that the transductive learning problems studied can give, we will see what is the effect of the number of measurements on the accuracy of both $p-$norm minimization problems.
#
# Towards this goal, you will write a `phase_transition()` function. This function will basically go over all the procedures that you have implemented in this section, but for varying numbers of measurements and thresholding values. It will also compute the relative error, $\text{rel-err},$ of the solutions and average them over a number of trials.
#
# The output of the `phase_transition()` function has to be a matrix with `len(mn_ratios)` columns and `len(thresholds)` rows. Each pixel $(i,j)$ in the output matrix has to contain the average, over `n_trials` trials, of the relative error $\text{rel-err}$ in the binarized (with threshold `thresholds[i]`) solution given by `graph_pnorm_interpolation()` from observing an `mn_ratios[j]` fraction of nodes. The randomness comes from a different choice of mask `w` at each trial, hence the averaging.
#
# The interest of this phase transition matrix is to assess what level of recovery error one could expect for a certain fraction of measurements and a certain threshold level.

# %%
def phase_transition(mn_ratios, thresholds, n_trials, labels_bin, p):

    # Create sample mask.
    
    # Solve p-norm interpolation.
    
    # Aggregate.
    row = len(thresholds)
    col = len(mn_ratios)
    pt_matrix = np.zeros([row, col])
    idx = np.array(np.meshgrid(np.arange(row), np.arange(col), np.arange(n_trials))).T.reshape(-1, 3)
    for i in idx:
        threshold_i = thresholds[i[0]]
        mn_ratios_i = mn_ratios[i[1]]
        m = int(mn_ratios_i * n_nodes)  # Number of measurements.
        w = np.ones_like(labels_bin)
        mask_idx = np.random.permutation(n_nodes)[0:(n_nodes - m)]
        w[mask_idx] = 0
        x0_bin = np.random.randn(n_nodes)
        x0_bin[w == 1] = labels_bin[w == 1]
        sol_p_norm_bin = graph_pnorm_interpolation(gradient, P, x0 = x0_bin, p=p, maxit = 3000)
        pred_label = np.zeros_like(sol_p_norm_bin) - 1
        pred_label[sol_p_norm_bin >= threshold_i] = 1
        pt_matrix[i[0], i[1]] += rel_err(labels_bin, pred_label)
    return pt_matrix / n_trials

# %% [markdown]
# ### Question 17
#
# Pick 5 "m/n" ratios in $(0, 1)$ and 5 threshold levels in $(-1, 1)$ and run the `phase_transition()` function with `n_trials` = 20, for both $p = 1$ and $p = 2$.

# %%
mn_ratios = np.matlib.linspace(0.2 * np.random.RandomState(8).rand(1), 1, 5, endpoint=False)
print('mn_ratios:', (*np.round(mn_ratios,2)))
thresholds = np.matlib.linspace(0.4 * np.random.RandomState(8).rand(1) - 1, 1, 5, endpoint=False)
print('thresholds:', (*np.round(thresholds,2)))
# Out:
# mn_ratios: 0.17 0.34 0.5 0.67 0.83
# thresholds: -0.65 -0.32 0.01 0.34 0.67

# %%
pt_matrix_1norm = phase_transition(mn_ratios, thresholds, n_trials=20, labels_bin=labels_bin, p=1)

pt_matrix_2norm = phase_transition(mn_ratios, thresholds, n_trials=20, labels_bin=labels_bin, p=2)
# Out:
# Solution found after 46 iterations:
#     objective function f(sol) = 3.366601e+04
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.822662e+05
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.867563e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.397024e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.155395e+04
#     stopping criterion: RTOL
# Solution found after 1036 iterations:
#     objective function f(sol) = 6.927231e+05
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.890921e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.501879e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.493373e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.071616e+04
#     stopping criterion: RTOL
# Solution found after 1039 iterations:
#     objective function f(sol) = 7.019879e+05
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.840463e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.600171e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.707480e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.149756e+04
#     stopping criterion: RTOL
# Solution found after 1003 iterations:
#     objective function f(sol) = 6.863886e+05
#     stopping criterion: RTOL
# Solution found after 991 iterations:
#     objective function f(sol) = 6.808882e+05
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.733528e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.297289e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.068007e+04
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.860206e+05
#     stopping criterion: RTOL
# Solution found after 991 iterations:
#     objective function f(sol) = 6.815811e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.064767e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.530876e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.154322e+04
#     stopping criterion: RTOL
# Solution found after 1013 iterations:
#     objective function f(sol) = 6.884126e+05
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.830511e+05
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 5.075371e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.659708e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.961911e+04
#     stopping criterion: RTOL
# Solution found after 998 iterations:
#     objective function f(sol) = 6.794424e+05
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.918700e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.319952e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.587032e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.328645e+04
#     stopping criterion: RTOL
# Solution found after 1037 iterations:
#     objective function f(sol) = 6.938737e+05
#     stopping criterion: RTOL
# Solution found after 986 iterations:
#     objective function f(sol) = 6.876529e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.029455e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.714555e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.127323e+04
#     stopping criterion: RTOL
# Solution found after 1036 iterations:
#     objective function f(sol) = 6.900319e+05
#     stopping criterion: RTOL
# Solution found after 1004 iterations:
#     objective function f(sol) = 6.905321e+05
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.809860e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.291448e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.959282e+04
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.841993e+05
#     stopping criterion: RTOL
# Solution found after 983 iterations:
#     objective function f(sol) = 6.808294e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.050344e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.652247e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.132601e+04
#     stopping criterion: RTOL
# Solution found after 1024 iterations:
#     objective function f(sol) = 6.983612e+05
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.846359e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.835137e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.535047e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.177142e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.486437e+04
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.827211e+05
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 4.759191e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.329912e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.975098e+04
#     stopping criterion: RTOL
# Solution found after 51 iterations:
#     objective function f(sol) = 3.399273e+04
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.805177e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.652345e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.686128e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.087038e+04
#     stopping criterion: RTOL
# Solution found after 1009 iterations:
#     objective function f(sol) = 6.879127e+05
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.839578e+05
#     stopping criterion: RTOL
# Solution found after 965 iterations:
#     objective function f(sol) = 6.819415e+05
#     stopping criterion: RTOL
# Solution found after 971 iterations:
#     objective function f(sol) = 6.884186e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.895209e+04
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.813474e+05
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.965074e+05
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.847708e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.560673e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.028498e+04
#     stopping criterion: RTOL
# Solution found after 1006 iterations:
#     objective function f(sol) = 6.799576e+05
#     stopping criterion: RTOL
# Solution found after 988 iterations:
#     objective function f(sol) = 6.801559e+05
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.855988e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.539696e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.115947e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 3.306422e+04
#     stopping criterion: RTOL
# Solution found after 991 iterations:
#     objective function f(sol) = 6.814589e+05
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 5.102053e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.650561e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.055426e+04
#     stopping criterion: RTOL
# Solution found after 1018 iterations:
#     objective function f(sol) = 6.970035e+05
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.804498e+05
#     stopping criterion: RTOL
# Solution found after 982 iterations:
#     objective function f(sol) = 6.910089e+05
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 5.626506e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.107583e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.743711e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 3.969560e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 4.977478e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.593031e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.060700e+04
#     stopping criterion: RTOL
# Solution found after 1004 iterations:
#     objective function f(sol) = 6.938831e+05
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.859822e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.379584e+03
#     stopping criterion: RTOL
# Solution found after 969 iterations:
#     objective function f(sol) = 6.856795e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.074169e+04
#     stopping criterion: RTOL
# Solution found after 1046 iterations:
#     objective function f(sol) = 7.019377e+05
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 3.977425e+04
#     stopping criterion: RTOL
# Solution found after 988 iterations:
#     objective function f(sol) = 6.903689e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.412456e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.071907e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 3.196510e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.050155e+04
#     stopping criterion: RTOL
# Solution found after 51 iterations:
#     objective function f(sol) = 4.947678e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.668953e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.073583e+04
#     stopping criterion: RTOL
# Solution found after 1034 iterations:
#     objective function f(sol) = 6.847589e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.308443e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.779892e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 5.689833e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.059954e+04
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.841956e+05
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.881991e+05
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.944652e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.649511e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.853066e+04
#     stopping criterion: RTOL
# Solution found after 1031 iterations:
#     objective function f(sol) = 6.910344e+05
#     stopping criterion: RTOL
# Solution found after 1010 iterations:
#     objective function f(sol) = 6.905414e+05
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 4.400824e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.564423e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.948374e+04
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.898434e+05
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 3.748705e+04
#     stopping criterion: RTOL
# Solution found after 49 iterations:
#     objective function f(sol) = 4.809764e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.575190e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.987051e+04
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.824949e+05
#     stopping criterion: RTOL
# Solution found after 967 iterations:
#     objective function f(sol) = 6.731442e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.854812e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.170914e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.204569e+04
#     stopping criterion: RTOL
# Solution found after 1031 iterations:
#     objective function f(sol) = 6.900927e+05
#     stopping criterion: RTOL
# Solution found after 1004 iterations:
#     objective function f(sol) = 6.921064e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.260008e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.666135e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.075063e+04
#     stopping criterion: RTOL
# Solution found after 1023 iterations:
#     objective function f(sol) = 6.915914e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.315813e+04
#     stopping criterion: RTOL
# Solution found after 981 iterations:
#     objective function f(sol) = 6.854661e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.621991e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.252345e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 3.376064e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.355144e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.829785e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.957869e+03
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.624413e+03
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.681955e+04
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.850892e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.153597e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.564787e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.041771e+04
#     stopping criterion: RTOL
# Solution found after 1007 iterations:
#     objective function f(sol) = 6.802025e+05
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.801322e+05
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.888302e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.477999e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.909931e+04
#     stopping criterion: RTOL
# Solution found after 1033 iterations:
#     objective function f(sol) = 6.951497e+05
#     stopping criterion: RTOL
# Solution found after 50 iterations:
#     objective function f(sol) = 4.316872e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.103624e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.669873e+03
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.153208e+04
#     stopping criterion: RTOL
# Solution found after 1009 iterations:
#     objective function f(sol) = 6.834845e+05
#     stopping criterion: RTOL
# Solution found after 1004 iterations:
#     objective function f(sol) = 6.861732e+05
#     stopping criterion: RTOL
# Solution found after 969 iterations:
#     objective function f(sol) = 6.797940e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.807105e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.099509e+04
#     stopping criterion: RTOL
# Solution found after 1025 iterations:
#     objective function f(sol) = 6.879227e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.688350e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.299927e+04
#     stopping criterion: RTOL
# Solution found after 988 iterations:
#     objective function f(sol) = 6.951485e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.144305e+04
#     stopping criterion: RTOL
# Solution found after 995 iterations:
#     objective function f(sol) = 6.799834e+05
#     stopping criterion: RTOL
# Solution found after 1023 iterations:
#     objective function f(sol) = 6.821154e+05
#     stopping criterion: RTOL
# Solution found after 50 iterations:
#     objective function f(sol) = 4.982295e+04
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.240930e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.015649e+04
#     stopping criterion: RTOL
# Solution found after 1035 iterations:
#     objective function f(sol) = 6.870837e+05
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.803942e+05
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.869890e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.893125e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.216118e+04
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.769752e+05
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.834889e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.007519e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.583902e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.052883e+04
#     stopping criterion: RTOL
# Solution found after 1023 iterations:
#     objective function f(sol) = 7.019892e+05
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.830640e+05
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.839031e+05
#     stopping criterion: RTOL
# Solution found after 977 iterations:
#     objective function f(sol) = 6.907363e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.128788e+04
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.794437e+05
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.813959e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.917229e+04
#     stopping criterion: RTOL
# Solution found after 979 iterations:
#     objective function f(sol) = 6.859162e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.959350e+04
#     stopping criterion: RTOL
# Solution found after 1007 iterations:
#     objective function f(sol) = 6.881716e+05
#     stopping criterion: RTOL
# Solution found after 1007 iterations:
#     objective function f(sol) = 6.844332e+05
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 4.917583e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.537510e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.092180e+04
#     stopping criterion: RTOL
# Solution found after 1019 iterations:
#     objective function f(sol) = 6.863886e+05
#     stopping criterion: RTOL
# Solution found after 983 iterations:
#     objective function f(sol) = 6.785281e+05
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 5.124747e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.557824e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.123013e+04
#     stopping criterion: RTOL
# Solution found after 1010 iterations:
#     objective function f(sol) = 6.840586e+05
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.795513e+05
#     stopping criterion: RTOL
# Solution found after 986 iterations:
#     objective function f(sol) = 6.876415e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.459984e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.155021e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.846600e+05
#     stopping criterion: RTOL
# Solution found after 1003 iterations:
#     objective function f(sol) = 6.872039e+05
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.840032e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.577910e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.206250e+04
#     stopping criterion: RTOL
# Solution found after 1006 iterations:
#     objective function f(sol) = 6.864610e+05
#     stopping criterion: RTOL
# Solution found after 1033 iterations:
#     objective function f(sol) = 6.916693e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.285157e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.680513e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.014638e+04
#     stopping criterion: RTOL
# Solution found after 996 iterations:
#     objective function f(sol) = 6.733399e+05
#     stopping criterion: RTOL
# Solution found after 998 iterations:
#     objective function f(sol) = 6.926157e+05
#     stopping criterion: RTOL
# Solution found after 995 iterations:
#     objective function f(sol) = 6.875299e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.332966e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.147061e+04
#     stopping criterion: RTOL
# Solution found after 1013 iterations:
#     objective function f(sol) = 6.911647e+05
#     stopping criterion: RTOL
# Solution found after 996 iterations:
#     objective function f(sol) = 6.910281e+05
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.901081e+05
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 5.650558e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.086235e+04
#     stopping criterion: RTOL
# Solution found after 1022 iterations:
#     objective function f(sol) = 6.899380e+05
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.842913e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.275536e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.505362e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.573109e+03
#     stopping criterion: RTOL
# Solution found after 1016 iterations:
#     objective function f(sol) = 6.791790e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.931343e+04
#     stopping criterion: RTOL
# Solution found after 998 iterations:
#     objective function f(sol) = 6.875899e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.586337e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.098060e+04
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 3.507520e+04
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.938495e+05
#     stopping criterion: RTOL
# Solution found after 1012 iterations:
#     objective function f(sol) = 6.756121e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.552729e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.044400e+04
#     stopping criterion: RTOL
# Solution found after 990 iterations:
#     objective function f(sol) = 6.774875e+05
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.781982e+05
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 6.925636e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.657414e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.197615e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.253033e+03
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.060466e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.770318e+04
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 5.880108e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.159911e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 3.230845e+04
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 4.132922e+04
#     stopping criterion: RTOL
# Solution found after 986 iterations:
#     objective function f(sol) = 6.886953e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.596298e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.217599e+04
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.798872e+05
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 4.320387e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.446549e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.509000e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.850400e+04
#     stopping criterion: RTOL
# Solution found after 1035 iterations:
#     objective function f(sol) = 6.923538e+05
#     stopping criterion: RTOL
# Solution found after 1011 iterations:
#     objective function f(sol) = 6.862114e+05
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 4.882690e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.314422e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.031751e+04
#     stopping criterion: RTOL
# Solution found after 1039 iterations:
#     objective function f(sol) = 6.930361e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.176833e+04
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 5.117769e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.723020e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.093082e+04
#     stopping criterion: RTOL
# Solution found after 1007 iterations:
#     objective function f(sol) = 6.860278e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.122473e+04
#     stopping criterion: RTOL
# Solution found after 984 iterations:
#     objective function f(sol) = 6.851408e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.651889e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.102225e+04
#     stopping criterion: RTOL
# Solution found after 1014 iterations:
#     objective function f(sol) = 6.808533e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.501632e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.194903e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.547560e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.018192e+04
#     stopping criterion: RTOL
# Solution found after 1024 iterations:
#     objective function f(sol) = 6.928565e+05
#     stopping criterion: RTOL
# Solution found after 998 iterations:
#     objective function f(sol) = 6.834117e+05
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 4.833843e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.415524e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.688347e+03
#     stopping criterion: RTOL
# Solution found after 1016 iterations:
#     objective function f(sol) = 6.908138e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.571270e+03
#     stopping criterion: RTOL
# Solution found after 981 iterations:
#     objective function f(sol) = 6.818183e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.543874e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.184195e+04
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 3.287966e+04
#     stopping criterion: RTOL
# Solution found after 994 iterations:
#     objective function f(sol) = 6.815387e+05
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.792778e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.209966e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.541586e+03
#     stopping criterion: RTOL
# Solution found after 6 iterations:
#     objective function f(sol) = 7.746626e+03
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.842546e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.133908e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.859783e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.025539e+04
#     stopping criterion: RTOL
# Solution found after 1027 iterations:
#     objective function f(sol) = 6.931287e+05
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.849517e+05
#     stopping criterion: RTOL
# Solution found after 972 iterations:
#     objective function f(sol) = 6.792793e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.504130e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.119077e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 3.294017e+04
#     stopping criterion: RTOL
# Solution found after 1001 iterations:
#     objective function f(sol) = 6.898161e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.296812e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.411826e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.059284e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 3.665037e+04
#     stopping criterion: RTOL
# Solution found after 992 iterations:
#     objective function f(sol) = 6.919734e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.767161e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.218474e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.129983e+04
#     stopping criterion: RTOL
# Solution found after 1021 iterations:
#     objective function f(sol) = 6.939068e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.632814e+03
#     stopping criterion: RTOL
# Solution found after 965 iterations:
#     objective function f(sol) = 6.774733e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.582661e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.076562e+04
#     stopping criterion: RTOL
# Solution found after 1044 iterations:
#     objective function f(sol) = 7.039839e+05
#     stopping criterion: RTOL
# Solution found after 1000 iterations:
#     objective function f(sol) = 6.797036e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.568810e+04
#     stopping criterion: RTOL
# Solution found after 968 iterations:
#     objective function f(sol) = 6.830295e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.111099e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.420969e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.102158e+03
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.419095e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.314363e+04
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 6.172471e+04
#     stopping criterion: RTOL
# Solution found after 1012 iterations:
#     objective function f(sol) = 6.878886e+05
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.891742e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.845791e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.679605e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.143361e+04
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 3.500846e+04
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.930533e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.596119e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.548535e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 6.189091e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 3.462113e+04
#     stopping criterion: RTOL
# Solution found after 988 iterations:
#     objective function f(sol) = 6.850430e+05
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 4.878720e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.371947e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.194766e+04
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.807349e+05
#     stopping criterion: RTOL
# Solution found after 1007 iterations:
#     objective function f(sol) = 6.950322e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 4.802288e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.661757e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.207583e+04
#     stopping criterion: RTOL
# Solution found after 1026 iterations:
#     objective function f(sol) = 7.000255e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 3.909533e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 4.298611e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.620070e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.171985e+04
#     stopping criterion: RTOL
# Solution found after 1006 iterations:
#     objective function f(sol) = 6.831437e+05
#     stopping criterion: RTOL
# Solution found after 1029 iterations:
#     objective function f(sol) = 6.904111e+05
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 4.515881e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.996459e+03
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.061298e+04
#     stopping criterion: RTOL
# Solution found after 999 iterations:
#     objective function f(sol) = 6.819544e+05
#     stopping criterion: RTOL
# Solution found after 1004 iterations:
#     objective function f(sol) = 6.843266e+05
#     stopping criterion: RTOL
# Solution found after 981 iterations:
#     objective function f(sol) = 6.870012e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.452656e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.894443e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 3.076669e+04
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 4.543923e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.831729e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.605155e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.162032e+04
#     stopping criterion: RTOL
# Solution found after 1007 iterations:
#     objective function f(sol) = 6.868530e+05
#     stopping criterion: RTOL
# Solution found after 994 iterations:
#     objective function f(sol) = 6.860313e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.087270e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.420353e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 6.058828e+04
#     stopping criterion: RTOL
# Solution found after 1005 iterations:
#     objective function f(sol) = 6.942420e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.850591e+04
#     stopping criterion: RTOL
# Solution found after 980 iterations:
#     objective function f(sol) = 6.862372e+05
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.661149e+03
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.900283e+04
#     stopping criterion: RTOL
# Solution found after 1038 iterations:
#     objective function f(sol) = 6.960871e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.986814e+04
#     stopping criterion: RTOL
# Solution found after 986 iterations:
#     objective function f(sol) = 6.797510e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.519202e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 6.000586e+04
#     stopping criterion: RTOL
# Solution found after 1003 iterations:
#     objective function f(sol) = 6.815144e+05
#     stopping criterion: RTOL
# Solution found after 991 iterations:
#     objective function f(sol) = 6.894036e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 4.099628e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.173377e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 6.083512e+04
#     stopping criterion: RTOL
# Solution found after 1002 iterations:
#     objective function f(sol) = 6.823785e+05
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 3.775828e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.742790e+04
#     stopping criterion: RTOL
# Solution found after 967 iterations:
#     objective function f(sol) = 6.857532e+05
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 5.607998e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.370526e+04
#     stopping criterion: RTOL
# Solution found after 985 iterations:
#     objective function f(sol) = 6.798595e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 4.476707e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.259586e+04
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 5.945546e+04
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.393917e+04
#     stopping criterion: RTOL
# Solution found after 993 iterations:
#     objective function f(sol) = 6.878856e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.111130e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 5.657862e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.811392e+04
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 3.298190e+04
#     stopping criterion: RTOL
# Solution found after 38 iterations:
#     objective function f(sol) = 3.817977e+04
#     stopping criterion: RTOL
# Solution found after 5 iterations:
#     objective function f(sol) = 8.388863e+03
#     stopping criterion: RTOL
# Solution found after 42 iterations:
#     objective function f(sol) = 5.317552e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.126401e+04
#     stopping criterion: RTOL
# Solution found after 1036 iterations:
#     objective function f(sol) = 6.937042e+05
#     stopping criterion: RTOL
# Solution found after 995 iterations:
#     objective function f(sol) = 6.797282e+05
#     stopping criterion: RTOL
# Solution found after 983 iterations:
#     objective function f(sol) = 6.797074e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 5.618729e+04
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 6.196728e+04
#     stopping criterion: RTOL
# Solution found after 1022 iterations:
#     objective function f(sol) = 6.923876e+05
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 3.909317e+04
#     stopping criterion: RTOL
# Solution found after 978 iterations:
#     objective function f(sol) = 6.864812e+05
#     stopping criterion: RTOL
# Solution found after 974 iterations:
#     objective function f(sol) = 6.925759e+05
#     stopping criterion: RTOL
# Solution found after 40 iterations:
#     objective function f(sol) = 6.019373e+04
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.861061e+05
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 6.844287e+05
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 4.831169e+04
#     stopping criterion: RTOL
# Solution found after 44 iterations:
#     objective function f(sol) = 5.350544e+04
#     stopping criterion: RTOL
# ...
#     objective function f(sol) = 2.774533e+04
#     stopping criterion: RTOL
# Solution found after 94 iterations:
#     objective function f(sol) = 2.516259e+04
#     stopping criterion: RTOL
# Solution found after 93 iterations:
#     objective function f(sol) = 2.605021e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 2.642005e+04
#     stopping criterion: RTOL
# Solution found after 141 iterations:
#     objective function f(sol) = 2.033485e+04
#     stopping criterion: RTOL
# Solution found after 73 iterations:
#     objective function f(sol) = 3.024650e+04
#     stopping criterion: RTOL
# Solution found after 88 iterations:
#     objective function f(sol) = 2.834684e+04
#     stopping criterion: RTOL
# Solution found after 104 iterations:
#     objective function f(sol) = 2.551820e+04
#     stopping criterion: RTOL
# Solution found after 123 iterations:
#     objective function f(sol) = 2.481745e+04
#     stopping criterion: RTOL
# Solution found after 135 iterations:
#     objective function f(sol) = 2.319909e+04
#     stopping criterion: RTOL
# Solution found after 76 iterations:
#     objective function f(sol) = 3.104698e+04
#     stopping criterion: RTOL
# Solution found after 100 iterations:
#     objective function f(sol) = 2.749537e+04
#     stopping criterion: RTOL
# Solution found after 84 iterations:
#     objective function f(sol) = 2.874787e+04
#     stopping criterion: RTOL
# Solution found after 132 iterations:
#     objective function f(sol) = 2.149777e+04
#     stopping criterion: RTOL
# Solution found after 144 iterations:
#     objective function f(sol) = 2.181556e+04
#     stopping criterion: RTOL
# Solution found after 70 iterations:
#     objective function f(sol) = 3.246191e+04
#     stopping criterion: RTOL
# Solution found after 82 iterations:
#     objective function f(sol) = 3.103555e+04
#     stopping criterion: RTOL
# Solution found after 118 iterations:
#     objective function f(sol) = 2.459038e+04
#     stopping criterion: RTOL
# Solution found after 120 iterations:
#     objective function f(sol) = 2.406966e+04
#     stopping criterion: RTOL
# Solution found after 136 iterations:
#     objective function f(sol) = 2.131982e+04
#     stopping criterion: RTOL
# Solution found after 100 iterations:
#     objective function f(sol) = 2.609283e+04
#     stopping criterion: RTOL
# Solution found after 85 iterations:
#     objective function f(sol) = 2.792396e+04
#     stopping criterion: RTOL
# Solution found after 111 iterations:
#     objective function f(sol) = 2.618058e+04
#     stopping criterion: RTOL
# Solution found after 122 iterations:
#     objective function f(sol) = 2.414515e+04
#     stopping criterion: RTOL
# Solution found after 137 iterations:
#     objective function f(sol) = 2.119375e+04
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 3.150862e+04
#     stopping criterion: RTOL
# Solution found after 102 iterations:
#     objective function f(sol) = 2.369238e+04
#     stopping criterion: RTOL
# Solution found after 101 iterations:
#     objective function f(sol) = 2.557568e+04
#     stopping criterion: RTOL
# Solution found after 101 iterations:
#     objective function f(sol) = 2.944590e+04
#     stopping criterion: RTOL
# Solution found after 114 iterations:
#     objective function f(sol) = 2.738976e+04
#     stopping criterion: RTOL
# Solution found after 62 iterations:
#     objective function f(sol) = 3.299345e+04
#     stopping criterion: RTOL
# Solution found after 75 iterations:
#     objective function f(sol) = 2.860259e+04
#     stopping criterion: RTOL
# Solution found after 121 iterations:
#     objective function f(sol) = 2.451627e+04
#     stopping criterion: RTOL
# Solution found after 139 iterations:
#     objective function f(sol) = 2.135865e+04
#     stopping criterion: RTOL
# Solution found after 138 iterations:
#     objective function f(sol) = 2.288720e+04
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 2.696957e+04
#     stopping criterion: RTOL
# Solution found after 69 iterations:
#     objective function f(sol) = 3.160424e+04
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 2.607521e+04
#     stopping criterion: RTOL
# Solution found after 138 iterations:
#     objective function f(sol) = 2.057922e+04
#     stopping criterion: RTOL
# Solution found after 141 iterations:
#     objective function f(sol) = 2.077065e+04
#     stopping criterion: RTOL
# Solution found after 65 iterations:
#     objective function f(sol) = 2.939136e+04
#     stopping criterion: RTOL
# Solution found after 69 iterations:
#     objective function f(sol) = 3.044523e+04
#     stopping criterion: RTOL
# Solution found after 99 iterations:
#     objective function f(sol) = 2.991413e+04
#     stopping criterion: RTOL
# Solution found after 121 iterations:
#     objective function f(sol) = 2.418509e+04
#     stopping criterion: RTOL
# Solution found after 138 iterations:
#     objective function f(sol) = 2.085881e+04
#     stopping criterion: RTOL
# Solution found after 66 iterations:
#     objective function f(sol) = 2.943209e+04
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.651578e+04
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 2.543846e+04
#     stopping criterion: RTOL
# Solution found after 120 iterations:
#     objective function f(sol) = 2.617243e+04
#     stopping criterion: RTOL
# Solution found after 134 iterations:
#     objective function f(sol) = 2.175168e+04
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 3.141786e+04
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 2.732771e+04
#     stopping criterion: RTOL
# Solution found after 87 iterations:
#     objective function f(sol) = 2.925431e+04
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 2.275491e+04
#     stopping criterion: RTOL
# Solution found after 143 iterations:
#     objective function f(sol) = 1.943481e+04
#     stopping criterion: RTOL
# Solution found after 108 iterations:
#     objective function f(sol) = 2.700838e+04
#     stopping criterion: RTOL
# Solution found after 95 iterations:
#     objective function f(sol) = 2.548727e+04
#     stopping criterion: RTOL
# Solution found after 114 iterations:
#     objective function f(sol) = 2.326934e+04
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 2.165044e+04
#     stopping criterion: RTOL
# Solution found after 138 iterations:
#     objective function f(sol) = 2.234259e+04
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.620615e+04
#     stopping criterion: RTOL
# Solution found after 82 iterations:
#     objective function f(sol) = 2.992046e+04
#     stopping criterion: RTOL
# Solution found after 116 iterations:
#     objective function f(sol) = 2.390517e+04
#     stopping criterion: RTOL
# Solution found after 115 iterations:
#     objective function f(sol) = 2.463459e+04
#     stopping criterion: RTOL
# Solution found after 146 iterations:
#     objective function f(sol) = 2.127781e+04
#     stopping criterion: RTOL
# Solution found after 74 iterations:
#     objective function f(sol) = 2.807508e+04
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 2.582519e+04
#     stopping criterion: RTOL
# Solution found after 100 iterations:
#     objective function f(sol) = 2.785137e+04
#     stopping criterion: RTOL
# Solution found after 132 iterations:
#     objective function f(sol) = 2.071781e+04
#     stopping criterion: RTOL
# Solution found after 144 iterations:
#     objective function f(sol) = 2.093201e+04
#     stopping criterion: RTOL
# Solution found after 51 iterations:
#     objective function f(sol) = 3.407548e+04
#     stopping criterion: RTOL
# Solution found after 101 iterations:
#     objective function f(sol) = 2.592159e+04
#     stopping criterion: RTOL
# Solution found after 86 iterations:
#     objective function f(sol) = 3.224250e+04
#     stopping criterion: RTOL
# Solution found after 127 iterations:
#     objective function f(sol) = 2.240296e+04
#     stopping criterion: RTOL
# Solution found after 140 iterations:
#     objective function f(sol) = 2.227188e+04
#     stopping criterion: RTOL
# Solution found after 55 iterations:
#     objective function f(sol) = 3.055985e+04
#     stopping criterion: RTOL
# Solution found after 77 iterations:
#     objective function f(sol) = 3.013999e+04
#     stopping criterion: RTOL
# Solution found after 105 iterations:
#     objective function f(sol) = 2.676431e+04
#     stopping criterion: RTOL
# Solution found after 141 iterations:
#     objective function f(sol) = 2.038144e+04
#     stopping criterion: RTOL
# Solution found after 139 iterations:
#     objective function f(sol) = 2.135521e+04
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 2.543229e+04
#     stopping criterion: RTOL
# Solution found after 88 iterations:
#     objective function f(sol) = 2.608380e+04
#     stopping criterion: RTOL
# Solution found after 107 iterations:
#     objective function f(sol) = 2.521285e+04
#     stopping criterion: RTOL
# Solution found after 142 iterations:
#     objective function f(sol) = 2.040287e+04
#     stopping criterion: RTOL
# Solution found after 131 iterations:
#     objective function f(sol) = 2.347141e+04
#     stopping criterion: RTOL
# Solution found after 61 iterations:
#     objective function f(sol) = 3.017055e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 3.544054e+04
#     stopping criterion: RTOL
# Solution found after 97 iterations:
#     objective function f(sol) = 2.831608e+04
#     stopping criterion: RTOL
# Solution found after 128 iterations:
#     objective function f(sol) = 2.409837e+04
#     stopping criterion: RTOL
# Solution found after 131 iterations:
#     objective function f(sol) = 2.256977e+04
#     stopping criterion: RTOL
# Solution found after 66 iterations:
#     objective function f(sol) = 3.025321e+04
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 3.116215e+04
#     stopping criterion: RTOL
# Solution found after 95 iterations:
#     objective function f(sol) = 2.781789e+04
#     stopping criterion: RTOL
# Solution found after 126 iterations:
#     objective function f(sol) = 2.444844e+04
#     stopping criterion: RTOL
# Solution found after 129 iterations:
#     objective function f(sol) = 2.442809e+04
#     stopping criterion: RTOL
# Solution found after 78 iterations:
#     objective function f(sol) = 2.569346e+04
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.540080e+04
#     stopping criterion: RTOL
# Solution found after 112 iterations:
#     objective function f(sol) = 2.452765e+04
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 2.118624e+04
#     stopping criterion: RTOL
# Solution found after 130 iterations:
#     objective function f(sol) = 2.420533e+04
#     stopping criterion: RTOL
# Solution found after 77 iterations:
#     objective function f(sol) = 3.188778e+04
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.433267e+04
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 3.060827e+04
#     stopping criterion: RTOL
# Solution found after 132 iterations:
#     objective function f(sol) = 2.133505e+04
#     stopping criterion: RTOL
# Solution found after 137 iterations:
#     objective function f(sol) = 2.242947e+04
#     stopping criterion: RTOL
# Solution found after 66 iterations:
#     objective function f(sol) = 2.947374e+04
#     stopping criterion: RTOL
# Solution found after 114 iterations:
#     objective function f(sol) = 2.398199e+04
#     stopping criterion: RTOL
# Solution found after 112 iterations:
#     objective function f(sol) = 2.435663e+04
#     stopping criterion: RTOL
# Solution found after 139 iterations:
#     objective function f(sol) = 2.070810e+04
#     stopping criterion: RTOL
# Solution found after 139 iterations:
#     objective function f(sol) = 2.146644e+04
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.711506e+04
#     stopping criterion: RTOL
# Solution found after 96 iterations:
#     objective function f(sol) = 2.858701e+04
#     stopping criterion: RTOL
# Solution found after 102 iterations:
#     objective function f(sol) = 2.793329e+04
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 2.315403e+04
#     stopping criterion: RTOL
# Solution found after 141 iterations:
#     objective function f(sol) = 2.108190e+04
#     stopping criterion: RTOL
# Solution found after 60 iterations:
#     objective function f(sol) = 3.032335e+04
#     stopping criterion: RTOL
# Solution found after 94 iterations:
#     objective function f(sol) = 2.568942e+04
#     stopping criterion: RTOL
# Solution found after 104 iterations:
#     objective function f(sol) = 2.436880e+04
#     stopping criterion: RTOL
# Solution found after 117 iterations:
#     objective function f(sol) = 2.495980e+04
#     stopping criterion: RTOL
# Solution found after 135 iterations:
#     objective function f(sol) = 2.304317e+04
#     stopping criterion: RTOL
# Solution found after 69 iterations:
#     objective function f(sol) = 3.019605e+04
#     stopping criterion: RTOL
# Solution found after 87 iterations:
#     objective function f(sol) = 2.776051e+04
#     stopping criterion: RTOL
# Solution found after 113 iterations:
#     objective function f(sol) = 2.514156e+04
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 2.278828e+04
#     stopping criterion: RTOL
# Solution found after 138 iterations:
#     objective function f(sol) = 2.037165e+04
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 2.575886e+04
#     stopping criterion: RTOL
# Solution found after 90 iterations:
#     objective function f(sol) = 2.573176e+04
#     stopping criterion: RTOL
# Solution found after 100 iterations:
#     objective function f(sol) = 2.640467e+04
#     stopping criterion: RTOL
# Solution found after 115 iterations:
#     objective function f(sol) = 2.533936e+04
#     stopping criterion: RTOL
# Solution found after 144 iterations:
#     objective function f(sol) = 2.098371e+04
#     stopping criterion: RTOL
# Solution found after 52 iterations:
#     objective function f(sol) = 3.066581e+04
#     stopping criterion: RTOL
# Solution found after 100 iterations:
#     objective function f(sol) = 2.615880e+04
#     stopping criterion: RTOL
# Solution found after 93 iterations:
#     objective function f(sol) = 2.763072e+04
#     stopping criterion: RTOL
# Solution found after 89 iterations:
#     objective function f(sol) = 3.151389e+04
#     stopping criterion: RTOL
# Solution found after 138 iterations:
#     objective function f(sol) = 2.139676e+04
#     stopping criterion: RTOL
# Solution found after 35 iterations:
#     objective function f(sol) = 3.591253e+04
#     stopping criterion: RTOL
# Solution found after 91 iterations:
#     objective function f(sol) = 2.575171e+04
#     stopping criterion: RTOL
# Solution found after 107 iterations:
#     objective function f(sol) = 2.456932e+04
#     stopping criterion: RTOL
# Solution found after 136 iterations:
#     objective function f(sol) = 2.283826e+04
#     stopping criterion: RTOL
# Solution found after 143 iterations:
#     objective function f(sol) = 2.012916e+04
#     stopping criterion: RTOL
# Solution found after 66 iterations:
#     objective function f(sol) = 3.251138e+04
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.590007e+04
#     stopping criterion: RTOL
# Solution found after 92 iterations:
#     objective function f(sol) = 2.928093e+04
#     stopping criterion: RTOL
# Solution found after 113 iterations:
#     objective function f(sol) = 2.715612e+04
#     stopping criterion: RTOL
# Solution found after 140 iterations:
#     objective function f(sol) = 2.112849e+04
#     stopping criterion: RTOL

# %% [markdown]
# Plot both phase transition matrices as images with a colorbar. Make sure to properly name the axes and title the images.

# %%
# Your code here.
pt_dict = {'pt_matrix_1norm': pt_matrix_1norm,
          'pt_matrix_2norm': pt_matrix_2norm}

# %%
fig, ax = plt.subplots(1,2, figsize=(12,10))
lower_bound = np.min([pt_matrix_1norm,pt_matrix_2norm])
upper_bound = np.max([pt_matrix_1norm,pt_matrix_2norm])
for i, key in enumerate(pt_dict.keys()):
    im = ax[i].imshow(pt_dict[key], cmap=cm.Blues, vmin=lower_bound, vmax = upper_bound)
    ax[i].set_title(key,fontdict={'fontsize':14})
    ax[i].set_xlabel('mn ratios index',fontdict={'fontsize':14})
    ax[i].set_ylabel('thresholds index',fontdict={'fontsize':14})

fig.subplots_adjust(bottom=0.1, top=0.9, left=-0.1, right=0.7,
                    wspace=0.15, hspace=0.2)
cb_ax = fig.add_axes([0.75, 0.2, 0.03, 0.6])
cbar = fig.colorbar(im, cax=cb_ax)

# %% [markdown]
# ### Question 18
#
# Do the phase transition plots above provide any justification for choosing one $p-$norm interpolation over the other? Why?

# %% [markdown]
# **Your answer here.**
#
# Yes. the p-norm with pt_matrix image most of which blocks are in light color may be the best choice, because light color means low relative color. Most of blocks are in light color represents the overall effect is good. Therefore, 2 norm works better than 1 norm.
